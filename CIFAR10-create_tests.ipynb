# %% [markdown]
# <a href="https://colab.research.google.com/github/as791/Adversarial-Example-Attack-and-Defense/blob/master/Adversarial_Example_(Attack_and_defense).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
from torchvision import transforms,datasets
from torch.autograd import Variable
import copy
from torch.autograd.gradcheck import zero_gradients
from scipy import optimize

# %%
np.random.seed(42)
torch.manual_seed(42)

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.0,), (1.0,))])
dataset = datasets.CIFAR10(root = './data', train=True, transform = transform, download=True)
train_set, val_set = torch.utils.data.random_split(dataset, [40000, 10000])
test_set = datasets.CIFAR10(root = './data', train=False, transform = transform, download=True)
train_loader = torch.utils.data.DataLoader(train_set,batch_size=128,shuffle=True)
val_loader = torch.utils.data.DataLoader(val_set,batch_size=128,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set,batch_size=1,shuffle=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print("Training data:",len(train_loader),"Validation data:",len(val_loader),"Test data: ",len(test_loader))
# Out:
# Training data: 313 Validation data: 79 Test data:  10000

# %%
use_cuda=True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %% [markdown]
# ##Attack

# %%
# NN Class model
class Net(nn.Module):
    def __init__(self):
      super().__init__() # To inherit all methods from parent class

      self.conv1 = nn.Conv2d(3, 64, 3, 1, padding=1) # args = (input_channels, output_channels, kernel_size, stride_length)
      self.conv2 = nn.Conv2d(64, 64, 3, 1, padding=1)
      self.conv3 = nn.Conv2d(64, 128, 3, 1, padding=1)
      self.conv4 = nn.Conv2d(128, 128, 3, 1, padding=1)

      # Calculations: 
      # No. of neurons in FC1 is (Number of channels)*(size of each channel after max pooling in conv3)
      # 32x32 -> conv1 -> 32x32 (after padding) -> conv2 -> 32x32 (after padding) -> max_pool1 -> 16x16 -> conv3 -> 16x16 (after padding) -> conv4 -> 16x16 (after padding) -> max_pool2 -> 8x8
      # size of each channel after max pooling in conv3 = 8*8
      # Number of channels = 128
      # No. of neurons in FC1 = 128*(8*8)

      self.fc1 = nn.Linear(8*8*128, 256)
      self.dropout1 = nn.Dropout(0.5)
      self.fc2 = nn.Linear(256, 256)
      self.dropout2 = nn.Dropout(0.5)
      self.fc3 = nn.Linear(256, 10)
    
    def forward(self, x):
      # Defining architecture of NN
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.max_pool2d(x, 2, 2)
      x = F.relu(self.conv3(x))
      x = F.relu(self.conv4(x))
      x = F.max_pool2d(x, 2, 2)
      x = x.view(-1, 8*8*128) # Flattens to 1x8*8*128 row vector
      x = F.relu(self.fc1(x))
      x = self.dropout1(x)
      x = F.relu(self.fc2(x))
      x = self.dropout2(x)
      x = self.fc3(x)
      x = F.log_softmax(x, dim=1)

      return x

# %%
model = Net().to(device)

# %%
#optimizer = optim.Adam(model.parameters(),lr=0.0001, betas=(0.9, 0.999))

optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, dampening =0.5,)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

criterion = nn.NLLLoss()
#scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)

# %%
def fit(model,device,train_loader,val_loader,epochs):
  data_loader = {'train':train_loader,'val':val_loader}
  print("Fitting the model...")
  train_loss,val_loss=[],[]
  for epoch in range(epochs):
    loss_per_epoch,val_loss_per_epoch=0,0
    for phase in ('train','val'):
      for i,data in enumerate(data_loader[phase]):
        input,label  = data[0].to(device),data[1].to(device)
        output = model(input)
        #calculating loss on the output
        loss = criterion(output,label)
        if phase == 'train':
          optimizer.zero_grad()
          #grad calc w.r.t Loss func
          loss.backward()
          #update weights
          optimizer.step()
          loss_per_epoch+=loss.item()
        else:
          val_loss_per_epoch+=loss.item()
    #scheduler.step(val_loss_per_epoch/len(val_loader))
    print("Epoch: {} Loss: {} Val_Loss: {}".format(epoch+1,loss_per_epoch/len(train_loader),val_loss_per_epoch/len(val_loader)))
    train_loss.append(loss_per_epoch/len(train_loader))
    val_loss.append(val_loss_per_epoch/len(val_loader))
  return train_loss,val_loss

# %%
def fit_and_save(model,devide,train_loader,val_loader,epochs,retrain):
    file_path = "./model/Exp1_CIFAR10.pth"
    if(retrain == True or not(os.path.exists(file_path))):
        loss,val_loss=fit(model,device,train_loader,val_loader,epochs)
        torch.save(model.state_dict(), file_path)
        np.save('./model/Exp1_CIFAR10_loss_array.npy', loss)
        np.save('./model/Exp1_CIFAR10_val_loss_array.npy', val_loss)
    else:
        model.load_state_dict(torch.load(file_path))
        loss = np.load('./model/Exp1_CIFAR10_loss_array.npy')
        val_loss = np.load('./model/Exp1_CIFAR10_val_loss_array.npy')
    return loss,val_loss

# %%
loss,val_loss=fit_and_save(model,device,train_loader,val_loader,50, False)

# %%
fig = plt.figure(figsize=(5,5))
plt.plot(np.arange(1,51), loss, "*-",label="Loss")
plt.plot(np.arange(1,51), val_loss,"o-",label="Val Loss")
plt.xlabel("Num of epochs")
plt.legend()
plt.show()

# %%
def fgsm_attack(input,epsilon,data_grad):
  pert_out = input + epsilon*data_grad.sign()
  pert_out = torch.clamp(pert_out, 0, 1)
  return pert_out

def mifgsm_attack(input,epsilon,data_grad):
  iter=10
  decay_factor=1.0
  pert_out = input
  alpha = epsilon/iter
  g=0
  for i in range(iter-1):
    g = decay_factor*g + data_grad/torch.norm(data_grad,p=1)
    pert_out = pert_out + alpha*torch.sign(g)
    pert_out = torch.clamp(pert_out, 0, 1)
    if torch.norm((pert_out-input),p=float('inf')) > epsilon:
      break
  return pert_out

# %%
def deepfool_attack(image, net, num_classes=10, overshoot = 0.02, max_iter=10):

    """
       :param image: Image of size HxWx3
       :param net: network (input: images, output: values of activation **BEFORE** softmax).
       :param num_classes: num_classes (limits the number of classes to test against, by default = 10)
       :param overshoot: used as a termination criterion to prevent vanishing updates (default = 0.02).
       :param max_iter: maximum number of iterations for deepfool (default = 50)
       :return: minimal perturbation that fools the classifier, number of iterations that it required, new estimated_label and perturbed image
    """
    is_cuda = torch.cuda.is_available()

    if is_cuda:
        #print("Using GPU")
        image = image.cuda()
        net = net.cuda()
    else:
        print("Using CPU")


    f_image = net.forward(Variable(image, requires_grad=True)).data.cpu().numpy().flatten()
    I = (np.array(f_image)).flatten().argsort()[::-1]

    I = I[0:num_classes]
    label = I[0]

    input_shape = image.cpu().detach().numpy().shape
    pert_image = copy.deepcopy(image)
    w = np.zeros(input_shape)
    r_tot = np.zeros(input_shape)

    loop_i = 0

    x = Variable(pert_image, requires_grad=True)
    fs = net.forward(x)
    fs_list = [fs[0,I[k]] for k in range(num_classes)]
    k_i = label

    while k_i == label and loop_i < max_iter:

        pert = np.inf
        fs[0, I[0]].backward(retain_graph=True)
        grad_orig = x.grad.data.cpu().numpy().copy()

        for k in range(1, num_classes):
            zero_gradients(x)

            fs[0, I[k]].backward(retain_graph=True)
            cur_grad = x.grad.data.cpu().numpy().copy()

            # set new w_k and new f_k
            w_k = cur_grad - grad_orig
            f_k = (fs[0, I[k]] - fs[0, I[0]]).data.cpu().numpy()

            pert_k = abs(f_k)/np.linalg.norm(w_k.flatten())

            # determine which w_k to use
            if pert_k < pert:
                pert = pert_k
                w = w_k

        # compute r_i and r_tot
        # Added 1e-4 for numerical stability
        r_i =  (pert+1e-4) * w / np.linalg.norm(w)
        r_tot = np.float32(r_tot + r_i)

        if is_cuda:
            pert_image = image + (1+overshoot)*torch.from_numpy(r_tot).cuda()
        else:
            pert_image = image + (1+overshoot)*torch.from_numpy(r_tot)

        x = Variable(pert_image, requires_grad=True)
        fs = net.forward(x)
        k_i = np.argmax(fs.data.cpu().numpy().flatten())

        loop_i += 1

    r_tot = (1+overshoot)*r_tot

    return pert_image

# %%
def flow_st(images,flows):
  images_shape = images.size()
  flows_shape = flows.size()
  batch_size = images_shape[0]
  H = images_shape[2]
  W = images_shape[3]
  basegrid = torch.stack(torch.meshgrid(torch.arange(0,H), torch.arange(0,W))) #(2,H,W)
  sampling_grid = basegrid.unsqueeze(0).type(torch.float32).cuda() + flows.cuda()
  sampling_grid_x = torch.clamp(sampling_grid[:,1],0.0,W-1.0).type(torch.float32)
  sampling_grid_y = torch.clamp(sampling_grid[:,0],0.0,H-1.0).type(torch.float32)

  x0 = torch.floor(sampling_grid_x).type(torch.int64)
  x1 = x0 + 1
  y0 = torch.floor(sampling_grid_y).type(torch.int64)
  y1 = y0 + 1

  x0 = torch.clamp(x0, 0, W - 2)
  x1 = torch.clamp(x1, 0, W - 1)
  y0 = torch.clamp(y0, 0, H - 2)
  y1 = torch.clamp(y1, 0, H - 1)
  
  Ia = images[:,:,y0[0,:,:], x0[0,:,:]]
  Ib = images[:,:,y1[0,:,:], x0[0,:,:]]
  Ic = images[:,:,y0[0,:,:], x1[0,:,:]]
  Id = images[:,:,y1[0,:,:], x1[0,:,:]]

  x0 = x0.type(torch.float32)
  x1 = x1.type(torch.float32)
  y0 = y0.type(torch.float32)
  y1 = y1.type(torch.float32)
  
  wa = (x1 - sampling_grid_x) * (y1 - sampling_grid_y)
  wb = (x1 - sampling_grid_x) * (sampling_grid_y - y0)
  wc = (sampling_grid_x - x0) * (y1 - sampling_grid_y)
  wd = (sampling_grid_x - x0) * (sampling_grid_y - y0)
  
  perturbed_image = wa.unsqueeze(0)*Ia+wb.unsqueeze(0)*Ib+wc.unsqueeze(0)*Ic+wd.unsqueeze(0)*Id

  return perturbed_image.type(torch.float32).cuda()

def flow_loss(flows,padding_mode='constant', epsilon=1e-8):
  paddings = (1,1,1,1)
  padded_flows = F.pad(flows,paddings,mode=padding_mode,value=0)
  shifted_flows = [
    padded_flows[:, :, 2:, 2:],  # bottom right (+1,+1)
    padded_flows[:, :, 2:, :-2],  # bottom left (+1,-1)
    padded_flows[:, :, :-2, 2:],  # top right (-1,+1)
    padded_flows[:, :, :-2, :-2]  # top left (-1,-1)
  ]
  #||\Delta u^{(p)} - \Delta u^{(q)}||_2^2 + # ||\Delta v^{(p)} - \Delta v^{(q)}||_2^2 
  loss=0
  for shifted_flow in shifted_flows:
    loss += torch.sum(torch.square(flows[:, 1] - shifted_flow[:, 1]) + torch.square(flows[:, 0] - shifted_flow[:, 0]) + epsilon).cuda()
  return loss.type(torch.float32)

def adv_loss(logits,targets,confidence=0.0):
  confidence=torch.tensor(confidence).cuda()
  real = torch.sum(logits*targets,-1)
  other = torch.max((1-targets)*logits-(targets*10000),-1)[0]
  return torch.max(other-real,confidence)[0].type(torch.float32)

def func(flows,input,target,model,const=0.05):
  input = torch.from_numpy(input).cuda()
  target = torch.from_numpy(target).cuda()
  flows = torch.from_numpy(flows).view((1,2,)+input.size()[2:]).cuda()
  flows.requires_grad=True
  pert_out = flow_st(input,flows)
  output = model(pert_out)
  L_flow = flow_loss(flows)
  L_adv = adv_loss(output,target)
  L_final = L_adv+const*L_flow
  model.zero_grad()
  L_final.backward()
  gradient = flows.grad.data.view(-1).detach().cpu().numpy()
  return L_final.item(),gradient

def spatial_attack(input,model,target):
  init_flows = np.zeros((1,2,)+input.size()[2:]).reshape(-1)
  results = optimize.fmin_l_bfgs_b(func,init_flows,args=(input.cpu().detach().numpy(),target.cpu().detach().numpy(),model))
  if b'CONVERGENCE' in results[2]['task']:
    flows = torch.from_numpy(results[0]).view((1,2,)+input.size()[2:])
    pert_out = flow_st(input,flows)
  else:
    return None
  return pert_out

# %%
def test_model(model,device,test_loader):
    correct = 0
    adv_examples = []
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1]
        if init_pred.item() == target.item():
            correct += 1
        else:
            adv_ex = data.squeeze().detach().cpu().numpy()
            adv_examples.append((target.item(), init_pred.item(), adv_ex))
            
    final_acc = correct/float(len(test_loader))
    print("Test Accuracy = {} / {} = {}".format(correct, len(test_loader), final_acc))
    
    return adv_examples
    
examples = test_model(model, device,test_loader)
# Out:
# Test Accuracy = 7139 / 10000 = 0.7139

# %%
from torch.utils.data import Dataset

class AugmentedDataset(Dataset):
    def __init__(self, X, y):
        # convert into PyTorch tensors and remember them
        self.X = X
        self.y = y
 
    def __len__(self):
        # this should return the size of the dataset
        return len(self.X)
 
    def __getitem__(self, idx):
        # this should return one sample from the dataset
        features = self.X[idx]
        target = self.y[idx]
        return features, target

# %%
def CreateTestDataset(model,device,loader,hyperparameter,attack):
  correct = 0
  X = []
  y = []
  i = 0
  for data, target in test_loader:
      if(i % 250 == 0):
        print(i/len(test_loader))
      i += 1
      data, target = data.to(device), target.to(device)
      data.requires_grad = True
      output = model(data)
      loss = F.nll_loss(output, target)
      model.zero_grad()
      loss.backward()
      data_grad = data.grad.data

      if attack == "fgsm":
        perturbed_data = fgsm_attack(data,hyperparameter,data_grad)
      elif attack == "mifgsm":
        perturbed_data = mifgsm_attack(data,hyperparameter,data_grad)
      elif attack == "deepfool":
        perturbed_data = deepfool_attack(data, model)
      elif attack == "spatial":
        random_target = hyperparameter
        attack_target = torch.from_numpy(np.expand_dims(np.eye(10, dtype=np.float32)[random_target],0)).cuda()
        perturbed_data = spatial_attack(data, model,attack_target)
    
      X.append(perturbed_data[0])
      y.append(target.item())

  return AugmentedDataset(X,y)

# %%
def CreateSpatialTestDataset(model,device,loader):
  correct = 0
  X = []
  y = []
  i = 0
  for data, target in test_loader:
    for attack_target in range(0, 10):
          if(i % 250 == 0):
            print(i/len(test_loader))
          i += 1
          data, target = data.to(device), target.to(device)
          data.requires_grad = True
          output = model(data)
          loss = F.nll_loss(output, target)
          model.zero_grad()
          loss.backward()
          data_grad = data.grad.data
          if attack_target != target.item():
              attack_target = torch.from_numpy(np.expand_dims(np.eye(10, dtype=np.float32)[attack_target],0)).cuda()
              perturbed_data = spatial_attack(data, model, attack_target)

              X.append(perturbed_data[0])
              y.append(target.item())

  return AugmentedDataset(X,y)

# %%
#fgsm_007_test = CreateTestDataset(model, device, test_loader, 0.007, "fgsm")
#print("fgsm 0.007 created")
#fgsm_01_test = CreateTestDataset(model, device, test_loader, 0.01, "fgsm")
#print("fgsm 0.01 created")
#fgsm_02_test = CreateTestDataset(model, device, test_loader, 0.02, "fgsm")
#print("fgsm 0.02 created")
#fgsm_03_test = CreateTestDataset(model, device, test_loader, 0.03, "fgsm")
#print("fgsm 0.03 created")
#fgsm_05_test = CreateTestDataset(model, device, test_loader, 0.05, "fgsm")
#print("fgsm 0.05 created")
#fgsm_1_test = CreateTestDataset(model, device, test_loader, 0.1, "fgsm")
#print("fgsm 0.1 created")
#fgsm_2_test = CreateTestDataset(model, device, test_loader, 0.2, "fgsm")
#print("fgsm 0.2 created")
#fgsm_3_test = CreateTestDataset(model, device, test_loader, 0.3, "fgsm")
#print("fgsm 0.3 created")


#mifgsm_007_test = CreateTestDataset(model, device, test_loader, 0.007, "mifgsm")
#print("mifgsm 0.007 created")
#mifgsm_01_test = CreateTestDataset(model, device, test_loader, 0.01, "mifgsm")
#print("mifgsm 0.01 created")
#mifgsm_02_test = CreateTestDataset(model, device, test_loader, 0.02, "mifgsm")
#print("mifgsm 0.02 created")
#mifgsm_03_test = CreateTestDataset(model, device, test_loader, 0.03, "mifgsm")
#print("mifgsm 0.03 created")
#mifgsm_05_test = CreateTestDataset(model, device, test_loader, 0.05, "mifgsm")
#print("mifgsm 0.05 created")
#mifgsm_1_test = CreateTestDataset(model, device, test_loader, 0.1, "mifgsm")
#print("mifgsm 0.1 created")
#mifgsm_2_test = CreateTestDataset(model, device, test_loader, 0.2, "mifgsm")
#print("mifgsm 0.2 created")
#mifgsm_3_test = CreateTestDataset(model, device, test_loader, 0.3, "mifgsm")
#print("mifgsm 0.3 created")

#deepfool_test = CreateTestDataset(model, device, test_loader, 0, "deepfool")
#print("deepfool created")

#spatial_test = CreateSpatialTestDataset(model, device, test_loader)
#print("spatial created")

#spatial_0_test = CreateTestDataset(model, device, test_loader, 0, "spatial")
#print("spatial created")
#spatial_1_test = CreateTestDataset(model, device, test_loader, 1, "spatial")
#print("spatial created")
#spatial_2_test = CreateTestDataset(model, device, test_loader, 2, "spatial")
#print("spatial created")
#spatial_3_test = CreateTestDataset(model, device, test_loader, 3, "spatial")
#print("spatial created")
#spatial_4_test = CreateTestDataset(model, device, test_loader, 4, "spatial")
#print("spatial created")
#spatial_5_test = CreateTestDataset(model, device, test_loader, 5, "spatial")
#print("spatial created")
#spatial_6_test = CreateTestDataset(model, device, test_loader, 6, "spatial")
#print("spatial created")
#spatial_7_test = CreateTestDataset(model, device, test_loader, 7, "spatial")
#print("spatial created")
spatial_8_test = CreateTestDataset(model, device, test_loader, 8, "spatial")
print("spatial created")
spatial_9_test = CreateTestDataset(model, device, test_loader, 9, "spatial")
print("spatial created")
# Out:
# 0.0
# 0.025
# 0.05
# 0.075
# 0.1
# 0.125
# 0.15
# 0.175
# 0.2
# 0.225
# 0.25
# 0.275
# 0.3
# 0.325
# 0.35
# 0.375
# 0.4
# 0.425
# 0.45
# 0.475
# 0.5
# 0.525
# 0.55
# 0.575
# 0.6
# 0.625
# 0.65
# 0.675
# 0.7
# 0.725
# 0.75
# 0.775
# 0.8
# 0.825
# 0.85
# 0.875
# 0.9
# 0.925
# 0.95
# 0.975
# spatial created
# 0.0
# 0.025
# 0.05
# 0.075
# 0.1
# 0.125
# 0.15
# 0.175
# 0.2
# 0.225
# 0.25
# 0.275
# 0.3
# 0.325
# 0.35
# 0.375
# 0.4
# 0.425
# 0.45
# 0.475
# 0.5
# 0.525
# 0.55
# 0.575
# 0.6
# 0.625
# 0.65
# 0.675
# 0.7
# 0.725
# 0.75
# 0.775
# 0.8
# 0.825
# 0.85
# 0.875
# 0.9
# 0.925
# 0.95
# 0.975
# spatial created

# %%
#torch.save(fgsm_007_test,'./custom_datasets/CIFAR10_fgsm_007_test.pth')
#torch.save(fgsm_01_test,'./custom_datasets/CIFAR10_fgsm_01_test.pth')
#torch.save(fgsm_02_test,'./custom_datasets/CIFAR10_fgsm_02_test.pth')
#torch.save(fgsm_03_test,'./custom_datasets/CIFAR10_fgsm_03_test.pth')
#torch.save(fgsm_05_test,'./custom_datasets/CIFAR10_fgsm_05_test.pth')
#torch.save(fgsm_1_test,'./custom_datasets/CIFAR10_fgsm_1_test.pth')
#torch.save(fgsm_2_test,'./custom_datasets/CIFAR10_fgsm_2_test.pth')
#torch.save(fgsm_3_test,'./custom_datasets/CIFAR10_fgsm_3_test.pth')

#torch.save(mifgsm_007_test,'./custom_datasets/CIFAR10_mifgsm_007_test.pth')
#torch.save(mifgsm_01_test,'./custom_datasets/CIFAR10_mifgsm_01_test.pth')
#torch.save(mifgsm_02_test,'./custom_datasets/CIFAR10_mifgsm_02_test.pth')
#torch.save(mifgsm_03_test,'./custom_datasets/CIFAR10_mifgsm_03_test.pth')
#torch.save(mifgsm_05_test,'./custom_datasets/CIFAR10_mifgsm_05_test.pth')
#torch.save(mifgsm_1_test,'./custom_datasets/CIFAR10_mifgsm_1_test.pth')
#torch.save(mifgsm_2_test,'./custom_datasets/CIFAR10_mifgsm_2_test.pth')
#torch.save(mifgsm_3_test,'./custom_datasets/CIFAR10_mifgsm_3_test.pth')

#torch.save(deepfool_test,'./custom_datasets/CIFAR10_deepfool_test.pth')

#torch.save(spatial_test,'./custom_datasets/CIFAR10_spatial_test.pth')

#torch.save(spatial_0_test,'./custom_datasets/CIFAR10_spatial_0_test.pth')
#torch.save(spatial_1_test,'./custom_datasets/CIFAR10_spatial_1_test.pth')
#torch.save(spatial_2_test,'./custom_datasets/CIFAR10_spatial_2_test.pth')
#torch.save(spatial_3_test,'./custom_datasets/CIFAR10_spatial_3_test.pth')
#torch.save(spatial_4_test,'./custom_datasets/CIFAR10_spatial_4_test.pth')
#torch.save(spatial_5_test,'./custom_datasets/CIFAR10_spatial_5_test.pth')
#torch.save(spatial_6_test,'./custom_datasets/CIFAR10_spatial_6_test.pth')
#torch.save(spatial_7_test,'./custom_datasets/CIFAR10_spatial_7_test.pth')
torch.save(spatial_8_test,'./custom_datasets/CIFAR10_spatial_8_test.pth')
torch.save(spatial_9_test,'./custom_datasets/CIFAR10_spatial_9_test.pth')

# %%
#fgsm_007_test = torch.load('./custom_datasets/CIFAR10_fgsm_007_test.pth')
#print(fgsm_007_test.X[0])
#fgsm_01_test = torch.load('./custom_datasets/CIFAR10_fgsm_01_test.pth')
#print(fgsm_01_test.X[0])
#fgsm_02_test = torch.load('./custom_datasets/CIFAR10_fgsm_02_test.pth')
#print(fgsm_02_test.X[0])
#fgsm_03_test = torch.load('./custom_datasets/CIFAR10_fgsm_03_test.pth')
#print(fgsm_03_test.X[0])
#fgsm_05_test = torch.load('./custom_datasets/CIFAR10_fgsm_05_test.pth')
#print(fgsm_05_test.X[0])
#fgsm_1_test = torch.load('./custom_datasets/CIFAR10_fgsm_1_test.pth')
#print(fgsm_1_test.X[0])
#fgsm_2_test = torch.load('./custom_datasets/CIFAR10_fgsm_2_test.pth')
#print(fgsm_2_test.X[0])
#fgsm_3_test = torch.load('./custom_datasets/CIFAR10_fgsm_3_test.pth')
#print(fgsm_3_test.X[0])

#mifgsm_007_test = torch.load('./custom_datasets/CIFAR10_mifgsm_007_test.pth')
#print(mifgsm_007_test.X[0])
#mifgsm_01_test = torch.load('./custom_datasets/CIFAR10_mifgsm_01_test.pth')
#print(mifgsm_01_test.X[0])
#mifgsm_02_test = torch.load('./custom_datasets/CIFAR10_mifgsm_02_test.pth')
#print(mifgsm_02_test.X[0])
#mifgsm_03_test = torch.load('./custom_datasets/CIFAR10_mifgsm_03_test.pth')
#print(mifgsm_03_test.X[0])
#mifgsm_05_test = torch.load('./custom_datasets/CIFAR10_mifgsm_05_test.pth')
#print(mifgsm_05_test.X[0])
#mifgsm_1_test = torch.load('./custom_datasets/CIFAR10_mifgsm_1_test.pth')
#print(mifgsm_1_test.X[0])
#mifgsm_2_test = torch.load('./custom_datasets/CIFAR10_mifgsm_2_test.pth')
#print(mifgsm_2_test.X[0])
#mifgsm_3_test = torch.load('./custom_datasets/CIFAR10_mifgsm_3_test.pth')
#print(mifgsm_3_test.X[0])

#deepfool_test = torch.load('./custom_datasets/CIFAR10_deepfool_test.pth')
#print(deepfool_test.X[0])

#spatial_test = torch.load('./custom_datasets/CIFAR10_spatial_test.pth')
#print(spatial_test.X[0])

#spatial_0_test = torch.load('./custom_datasets/CIFAR10_spatial_0_test.pth')
#print(spatial_0_test.X[0])
#spatial_1_test = torch.load('./custom_datasets/CIFAR10_spatial_1_test.pth')
#print(spatial_1_test.X[0])
#spatial_2_test = torch.load('./custom_datasets/CIFAR10_spatial_2_test.pth')
#print(spatial_2_test.X[0])
#spatial_3_test = torch.load('./custom_datasets/CIFAR10_spatial_3_test.pth')
#print(spatial_3_test.X[0])
#spatial_4_test = torch.load('./custom_datasets/CIFAR10_spatial_4_test.pth')
#print(spatial_4_test.X[0])
#spatial_5_test = torch.load('./custom_datasets/CIFAR10_spatial_5_test.pth')
#print(spatial_5_test.X[0])
#spatial_6_test = torch.load('./custom_datasets/CIFAR10_spatial_6_test.pth')
#print(spatial_6_test.X[0])
#spatial_7_test = torch.load('./custom_datasets/CIFAR10_spatial_7_test.pth')
#print(spatial_7_test.X[0])
spatial_8_test = torch.load('./custom_datasets/CIFAR10_spatial_8_test.pth')
print(spatial_8_test.X[0])
spatial_9_test = torch.load('./custom_datasets/CIFAR10_spatial_9_test.pth')
print(spatial_9_test.X[0])
# Out:
# tensor([[[0.3765, 0.4549, 0.5255,  ..., 0.6510, 0.7137, 0.7176],
#          [0.4235, 0.4941, 0.5569,  ..., 0.8078, 0.8980, 0.9098],
#          [0.4667, 0.5255, 0.5765,  ..., 0.8353, 0.9451, 0.9216],
#          ...,
#          [0.2196, 0.2157, 0.3176,  ..., 0.0863, 0.0824, 0.0902],
#          [0.2000, 0.2353, 0.3373,  ..., 0.0784, 0.0824, 0.0902],
#          [0.2431, 0.2431, 0.2941,  ..., 0.0745, 0.0784, 0.0824]],
#
#         [[0.4314, 0.5059, 0.5765,  ..., 0.5333, 0.5137, 0.5294],
#          [0.4745, 0.5412, 0.6039,  ..., 0.2980, 0.1882, 0.2431],
#          [0.5098, 0.5608, 0.6157,  ..., 0.2196, 0.1373, 0.1412],
#          ...,
#          [0.2549, 0.2549, 0.3490,  ..., 0.1137, 0.1216, 0.1333],
#          [0.2353, 0.2706, 0.3725,  ..., 0.1137, 0.1176, 0.1255],
#          [0.2824, 0.2784, 0.3294,  ..., 0.1059, 0.1137, 0.1176]],
#
#         [[0.4706, 0.5647, 0.6235,  ..., 0.6392, 0.6039, 0.6588],
#          [0.5176, 0.6000, 0.6510,  ..., 0.4510, 0.3373, 0.4000],
#          [0.5529, 0.6275, 0.6667,  ..., 0.3804, 0.2863, 0.2667],
#          ...,
#          [0.2431, 0.2627, 0.3608,  ..., 0.1333, 0.1490, 0.1412],
#          [0.2353, 0.2667, 0.3725,  ..., 0.1255, 0.1490, 0.1412],
#          [0.2784, 0.2745, 0.3294,  ..., 0.1216, 0.1451, 0.1373]]],
#        device='cuda:0', requires_grad=True)
# tensor([[[0.6231, 0.5688, 0.5531,  ..., 0.5570, 0.5851, 0.6275],
#          [0.5766, 0.5881, 0.5458,  ..., 0.4175, 0.4531, 0.5157],
#          [0.5061, 0.5254, 0.5258,  ..., 0.4734, 0.4894, 0.5027],
#          ...,
#          [0.4083, 0.4161, 0.3892,  ..., 0.5331, 0.5625, 0.4896],
#          [0.3805, 0.3770, 0.4196,  ..., 0.4485, 0.4664, 0.4432],
#          [0.3960, 0.3883, 0.4315,  ..., 0.4706, 0.4382, 0.3882]],
#
#         [[0.5216, 0.4905, 0.4747,  ..., 0.4238, 0.4680, 0.5333],
#          [0.5333, 0.5333, 0.4795,  ..., 0.3540, 0.3744, 0.4370],
#          [0.4904, 0.5058, 0.5017,  ..., 0.3854, 0.3949, 0.4200],
#          ...,
#          [0.3653, 0.3550, 0.3306,  ..., 0.3920, 0.4115, 0.4429],
#          [0.3492, 0.3147, 0.3688,  ..., 0.3622, 0.3962, 0.4275],
#          [0.4073, 0.3531, 0.3766,  ..., 0.4510, 0.4336, 0.3725]],
#
#         [[0.2009, 0.2750, 0.3055,  ..., 0.2825, 0.3111, 0.3765],
#          [0.3020, 0.3369, 0.3488,  ..., 0.2639, 0.2569, 0.3071],
#          [0.3255, 0.3489, 0.3606,  ..., 0.3092, 0.3065, 0.2986],
#          ...,
#          [0.2319, 0.2347, 0.2161,  ..., 0.2180, 0.2463, 0.2468],
#          [0.2275, 0.2201, 0.2276,  ..., 0.2558, 0.2317, 0.2275],
#          [0.2431, 0.2549, 0.2548,  ..., 0.2784, 0.2587, 0.2588]]],
#        device='cuda:0', requires_grad=True)

# %%
#fgsm_007_test_loader = torch.utils.data.DataLoader(fgsm_007_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_007_test_loader)
#fgsm_01_test_loader = torch.utils.data.DataLoader(fgsm_01_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_01_test_loader)
#fgsm_02_test_loader = torch.utils.data.DataLoader(fgsm_02_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_02_test_loader)
#fgsm_03_test_loader = torch.utils.data.DataLoader(fgsm_03_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_03_test_loader)
#fgsm_05_test_loader = torch.utils.data.DataLoader(fgsm_05_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_05_test_loader)
#fgsm_1_test_loader = torch.utils.data.DataLoader(fgsm_1_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_1_test_loader)
#fgsm_2_test_loader = torch.utils.data.DataLoader(fgsm_2_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_2_test_loader)
#fgsm_3_test_loader = torch.utils.data.DataLoader(fgsm_3_test,batch_size=1,shuffle=True)
#test_model(model, device,fgsm_3_test_loader)

#mifgsm_007_test_loader = torch.utils.data.DataLoader(mifgsm_007_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_007_test_loader)
#mifgsm_01_test_loader = torch.utils.data.DataLoader(mifgsm_01_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_01_test_loader)
#mifgsm_02_test_loader = torch.utils.data.DataLoader(mifgsm_02_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_02_test_loader)
#mifgsm_03_test_loader = torch.utils.data.DataLoader(mifgsm_03_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_03_test_loader)
#mifgsm_05_test_loader = torch.utils.data.DataLoader(mifgsm_05_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_05_test_loader)
#mifgsm_1_test_loader = torch.utils.data.DataLoader(mifgsm_1_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_1_test_loader)
#mifgsm_2_test_loader = torch.utils.data.DataLoader(mifgsm_2_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_2_test_loader)
#mifgsm_3_test_loader = torch.utils.data.DataLoader(mifgsm_3_test,batch_size=1,shuffle=True)
#test_model(model, device,mifgsm_3_test_loader)

#deepfool_test_loader = torch.utils.data.DataLoader(deepfool_test,batch_size=1,shuffle=True)
#test_model(model, device,deepfool_test_loader)

#spatial_test_loader = torch.utils.data.DataLoader(spatial_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_test_loader)

#spatial_0_test_loader = torch.utils.data.DataLoader(spatial_0_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_0_test_loader)
#spatial_1_test_loader = torch.utils.data.DataLoader(spatial_1_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_1_test_loader)
#spatial_2_test_loader = torch.utils.data.DataLoader(spatial_2_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_2_test_loader)
#spatial_3_test_loader = torch.utils.data.DataLoader(spatial_3_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_3_test_loader)
#spatial_4_test_loader = torch.utils.data.DataLoader(spatial_4_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_4_test_loader)
#spatial_5_test_loader = torch.utils.data.DataLoader(spatial_5_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_5_test_loader)
#spatial_6_test_loader = torch.utils.data.DataLoader(spatial_6_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_6_test_loader)
#spatial_7_test_loader = torch.utils.data.DataLoader(spatial_7_test,batch_size=1,shuffle=True)
#test_model(model, device,spatial_7_test_loader)
spatial_8_test_loader = torch.utils.data.DataLoader(spatial_8_test,batch_size=1,shuffle=True)
test_model(model, device,spatial_8_test_loader)
spatial_9_test_loader = torch.utils.data.DataLoader(spatial_9_test,batch_size=1,shuffle=True)
test_model(model, device,spatial_9_test_loader)
# Out:
# Test Accuracy = 6061 / 10000 = 0.6061
# Test Accuracy = 6093 / 10000 = 0.6093
# [(2,
#   3,
#   array([[[0.4862745 , 0.4862745 , 0.4862745 , ..., 0.46274108,
#            0.45094824, 0.43137255],
#           [0.5173381 , 0.51340246, 0.5174026 , ..., 0.47837904,
#            0.47044688, 0.454919  ],
#           [0.54497063, 0.54125965, 0.5453139 , ..., 0.4980143 ,
#            0.4862599 , 0.4745216 ],
#           ...,
#           [0.7568521 , 0.7555434 , 0.77217853, ..., 0.6038223 ,
#            0.5796519 , 0.54133415],
#           [0.68152153, 0.6911981 , 0.6986955 , ..., 0.5542977 ,
#            0.52270323, 0.5059294 ],
#           [0.5137255 , 0.53723586, 0.57185006, ..., 0.40665376,
#            0.37920037, 0.44705883]],
#
#          [[0.5176471 , 0.5137271 , 0.5137255 , ..., 0.48627317,
#            0.48234007, 0.4745098 ],
#           [0.5487107 , 0.54472667, 0.54485565, ..., 0.50972986,
#            0.5018532 , 0.4980597 ],
#           [0.57634324, 0.57263225, 0.5766864 , ..., 0.54115   ,
#            0.53331345, 0.52158046],
#           ...,
#           [0.7921569 , 0.7907369 , 0.80745417, ..., 0.635187  ,
#            0.61113364, 0.5883496 ],
#           [0.7166228 , 0.7225706 , 0.7301016 , ..., 0.581831  ,
#            0.5578993 , 0.54907197],
#           [0.54509807, 0.5686084 , 0.60322255, ..., 0.43795845,
#            0.40679756, 0.47843137]],
#
#          [[0.46666667, 0.47450662, 0.48627105, ..., 0.4548993 ,
#            0.44704595, 0.4392157 ],
#           [0.49773982, 0.50551486, 0.5135092 , ..., 0.474451  ,
#            0.47045022, 0.46275875],
#           [0.5253629 , 0.5216597 , 0.5295916 , ..., 0.49017805,
#            0.48234585, 0.47844556],
#           ...,
#           [0.7254903 , 0.7241715 , 0.7369078 , ..., 0.5842144 ,
#            0.560136  , 0.5334585 ],
#           [0.65484154, 0.66084635, 0.66728944, ..., 0.5348268 ,
#            0.5071084 , 0.49416992],
#           [0.5019608 , 0.5176344 , 0.54432917, ..., 0.39472905,
#            0.3673198 , 0.42745098]]], dtype=float32)),
#  (3,
#   0,
#   array([[[0.46669328, 0.52553236, 0.54904515, ..., 0.7333318 ,
#            0.72548157, 0.733333  ],
#           [0.43528977, 0.4946895 , 0.5646955 , ..., 0.733273  ,
#            0.7137593 , 0.7294298 ],
#           [0.40402123, 0.40332964, 0.5762968 , ..., 0.73756546,
#            0.74435115, 0.7607729 ],
#           ...,
#           [0.4901613 , 0.44736925, 0.49683705, ..., 0.74302715,
#            0.80807316, 0.85892427],
#           [0.48212567, 0.49364233, 0.4546374 , ..., 0.68617743,
#            0.6708737 , 0.8772696 ],
#           [0.4392157 , 0.50549304, 0.4415076 , ..., 0.6823515 ,
#            0.67511445, 0.7849803 ]],
#
#          [[0.62749004, 0.7137817 , 0.74511707, ..., 0.6235297 ,
#            0.6235177 , 0.62352943],
#           [0.58038497, 0.65961987, 0.7450896 , ..., 0.62739056,
#            0.6078807 , 0.62354296],
#           [0.52941644, 0.5528114 , 0.74879   , ..., 0.6208029 ,
#            0.6113678 , 0.64704716],
#           ...,
#           [0.6548635 , 0.6081566 , 0.5754892 , ..., 0.6650772 ,
#            0.7335272 , 0.7649275 ],
#           [0.6429307 , 0.654329  , 0.6009747 , ..., 0.62339026,
#            0.6004421 , 0.80674464],
#           [0.6039216 , 0.6702177 , 0.6094832 , ..., 0.64705676,
#            0.6358772 , 0.7416486 ]],
#
#          [[0.27453464, 0.32946095, 0.3568945 , ..., 0.55686146,
#            0.5529175 , 0.5411771 ],
#           [0.25882265, 0.2985897 , 0.36470175, ..., 0.54893553,
#            0.52163035, 0.52550375],
#           [0.25106236, 0.2419119 , 0.38809046, ..., 0.5462453 ,
#            0.52127665, 0.54900897],
#           ...,
#           [0.32154143, 0.28664806, 0.2871607 , ..., 0.60270697,
#            0.6630266 , 0.7138867 ],
#           [0.3213827 , 0.34442267, 0.28501156, ..., 0.568558  ,
#            0.5570921 , 0.7440798 ],
#           [0.28627452, 0.35644984, 0.28876197, ..., 0.58039427,
#            0.59261036, 0.6750097 ]]], dtype=float32)),
#  (0,
#   3,
#   array([[[0.5058824 , 0.5098015 , 0.51764554, ..., 0.6862729 ,
#            0.6392502 , 0.74799025],
#           [0.5058787 , 0.5097822 , 0.5176422 , ..., 0.6824219 ,
#            0.702216  , 0.65495026],
#           [0.49408853, 0.49802884, 0.5097995 , ..., 0.69836396,
#            0.7567345 , 0.6666903 ],
#           ...,
#           [0.25485888, 0.23918344, 0.2235047 , ..., 0.13344605,
#            0.17649023, 0.18824136],
#           [0.21578738, 0.21578032, 0.21962778, ..., 0.13337854,
#            0.16080156, 0.18038468],
#           [0.20002465, 0.20004715, 0.18855475, ..., 0.12946787,
#            0.15294795, 0.16081461]],
#
#          [[0.54901963, 0.55293876, 0.5607829 , ..., 0.69412005,
#            0.64709336, 0.7597358 ],
#           [0.54901594, 0.5529194 , 0.56077945, ..., 0.6902651 ,
#            0.7100798 , 0.6667113 ],
#           [0.5372258 , 0.5411661 , 0.5529368 , ..., 0.7062356 ,
#            0.7684984 , 0.67846286],
#           ...,
#           [0.22348633, 0.2078109 , 0.19213216, ..., 0.12943304,
#            0.13724163, 0.1294148 ],
#           [0.18441485, 0.18440777, 0.18825524, ..., 0.13722979,
#            0.12549876, 0.12548721],
#           [0.16865212, 0.16867462, 0.1571822 , ..., 0.14114828,
#            0.12940443, 0.11765918]],
#
#          [[0.6196078 , 0.623527  , 0.63137114, ..., 0.74900055,
#            0.6941557 , 0.7950669 ],
#           [0.6196042 , 0.6235077 , 0.6313677 , ..., 0.7412204 ,
#            0.75318927, 0.6980925 ],
#           [0.607814  , 0.6117544 , 0.623525  , ..., 0.75321907,
#            0.8037789 , 0.7019765 ],
#           ...,
#           [0.21172163, 0.19604619, 0.18036747, ..., 0.10985526,
#            0.12940508, 0.12549627],
#           [0.17265014, 0.17264307, 0.17649053, ..., 0.11372907,
#            0.11765678, 0.12156414],
#           [0.1568874 , 0.15690991, 0.14541751, ..., 0.1176375 ,
#            0.1137249 , 0.10982209]]], dtype=float32)),
#  (4,
#   0,
#   array([[[0.43529412, 0.43531042, 0.43529895, ..., 0.44706824,
#            0.44706717, 0.45489842],
#           [0.431379  , 0.44309586, 0.4352987 , ..., 0.44709185,
#            0.45490083, 0.45489407],
#           [0.43138483, 0.43528518, 0.43137652, ..., 0.44707227,
#            0.44709483, 0.4470855 ],
#           ...,
#           [0.35274947, 0.40555355, 0.3400154 , ..., 0.2946954 ,
#            0.28799772, 0.25466928],
#           [0.32743958, 0.3768438 , 0.36967555, ..., 0.28209987,
#            0.272199  , 0.23840761],
#           [0.23990211, 0.27934575, 0.2698651 , ..., 0.2933766 ,
#            0.23532863, 0.19446078]],
#
#          [[0.6       , 0.59610313, 0.60000896, ..., 0.61569005,
#            0.6156929 , 0.6196061 ],
#           [0.6000043 , 0.60781145, 0.6039237 , ..., 0.6157193 ,
#            0.6235283 , 0.6235215 ],
#           [0.6000082 , 0.5999911 , 0.59608245, ..., 0.6117943 ,
#            0.61572236, 0.61571294],
#           ...,
#           [0.3644822 , 0.40908042, 0.33254755, ..., 0.32580644,
#            0.3193703 , 0.28604183],
#           [0.33553994, 0.3774866 , 0.36251453, ..., 0.31290177,
#            0.30357155, 0.26978016],
#           [0.25944355, 0.29876444, 0.28485137, ..., 0.31957427,
#            0.26669854, 0.22583334]],
#
#          [[0.7490196 , 0.74512255, 0.74511594, ..., 0.75294495,
#            0.74903035, 0.75685924],
#           [0.74902385, 0.75683105, 0.7529433 , ..., 0.75297415,
#            0.7607832 , 0.76077646],
#           [0.74902785, 0.7490106 , 0.7451021 , ..., 0.7529546 ,
#            0.75297725, 0.75296783],
#           ...,
#           [0.2155265 , 0.22120807, 0.14975843, ..., 0.24831885,
#            0.23692162, 0.20363069],
#           [0.19607843, 0.21222188, 0.19278517, ..., 0.22761254,
#            0.21742396, 0.183573  ],
#           [0.19622079, 0.22727273, 0.21133055, ..., 0.23246421,
#            0.18434294, 0.14337698]]], dtype=float32)),
#  (5,
#   4,
#   array([[[3.9215689e-03, 7.8429775e-03, 2.3525994e-02, ...,
#            4.4312668e-01, 4.0786052e-01, 4.0392381e-01],
#           [7.8428816e-03, 1.9610770e-02, 4.7050834e-02, ...,
#            4.8235554e-01, 4.4317424e-01, 4.1572368e-01],
#           [1.5686119e-02, 3.5314988e-02, 7.0585519e-02, ...,
#            4.8234558e-01, 4.5883432e-01, 4.3530732e-01],
#           ...,
#           [6.4717793e-01, 7.0590436e-01, 7.2937810e-01, ...,
#            9.5290583e-01, 9.0200651e-01, 8.7453377e-01],
#           [6.6672015e-01, 7.1767253e-01, 7.6855356e-01, ...,
#            9.2937219e-01, 8.9806211e-01, 8.7061048e-01],
#           [6.4315885e-01, 6.7451513e-01, 7.2934675e-01, ...,
#            8.6274230e-01, 8.3930182e-01, 8.1578732e-01]],
#
#          [[0.0000000e+00, 3.9214087e-03, 8.5456702e-07, ...,
#            4.2744160e-01, 3.9609388e-01, 3.9215913e-01],
#           [3.9213123e-03, 3.9215689e-03, 3.9209304e-03, ...,
#            4.6274605e-01, 4.2748496e-01, 4.0395555e-01],
#           [3.9215689e-03, 3.9243768e-03, 7.8427745e-03, ...,
#            4.5490253e-01, 4.4314393e-01, 4.2354113e-01],
#           ...,
#           [6.0795522e-01, 6.6276437e-01, 6.8231440e-01, ...,
#            8.9016080e-01, 8.3926141e-01, 8.1570715e-01],
#           [6.2749940e-01, 6.7453033e-01, 7.1758080e-01, ...,
#            8.6662513e-01, 8.3531702e-01, 8.1178457e-01],
#           [6.0394150e-01, 6.3137770e-01, 6.8229258e-01, ...,
#            7.9607654e-01, 7.8046983e-01, 7.5696379e-01]],
#
#          [[3.9215689e-03, 1.6034819e-07, 0.0000000e+00, ...,
#            3.9607021e-01, 3.6864096e-01, 3.6862814e-01],
#           [2.5665059e-07, 1.4336803e-11, 0.0000000e+00, ...,
#            4.2745116e-01, 3.9610600e-01, 3.7258038e-01],
#           [0.0000000e+00, 2.8072504e-06, 3.9212056e-03, ...,
#            4.1568899e-01, 4.0392739e-01, 3.8824448e-01],
#           ...,
#           [5.6871563e-01, 6.1178112e-01, 6.2741333e-01, ...,
#            8.2741457e-01, 7.7651638e-01, 7.4904388e-01],
#           [5.8435452e-01, 6.2354743e-01, 6.6268611e-01, ...,
#            7.9995942e-01, 7.7256978e-01, 7.4903417e-01],
#           [5.6080425e-01, 5.8823955e-01, 6.3132149e-01, ...,
#            7.2940993e-01, 7.1380824e-01, 6.9812936e-01]]], dtype=float32)),
#  (0,
#   6,
#   array([[[0.8509804 , 0.7647034 , 0.76078635, ..., 0.7647434 ,
#            0.5135716 , 0.23921569],
#           [0.85489756, 0.7609773 , 0.72958946, ..., 0.77827144,
#            0.54133373, 0.29944426],
#           [0.8431004 , 0.72976613, 0.69804794, ..., 0.7459399 ,
#            0.48649496, 0.29887563],
#           ...,
#           [0.8414461 , 0.90595216, 0.9426859 , ..., 0.55151194,
#            0.39187518, 0.36860344],
#           [0.72181433, 0.79351723, 0.87158   , ..., 0.32278672,
#            0.4077134 , 0.37646917],
#           [0.654902  , 0.7095403 , 0.8026284 , ..., 0.21329172,
#            0.36506048, 0.36862746]],
#
#          [[0.654902  , 0.5960685 , 0.5804002 , ..., 0.35301784,
#            0.2862789 , 0.29411766],
#           [0.6509849 , 0.59228253, 0.5648352 , ..., 0.38367182,
#            0.3216062 , 0.32156706],
#           [0.6274476 , 0.5649227 , 0.5568619 , ..., 0.40110716,
#            0.30597788, 0.31759843],
#           ...,
#           [0.6757279 , 0.7255293 , 0.7471895 , ..., 0.5590405 ,
#            0.41167757, 0.40392157],
#           [0.58448327, 0.6293529 , 0.6898405 , ..., 0.31963295,
#            0.423476  , 0.415687  ],
#           [0.52156866, 0.5527906 , 0.62279046, ..., 0.22150803,
#            0.39258698, 0.41960785]],
#
#          [[0.43137255, 0.4235443 , 0.4470468 , ..., 0.17260037,
#            0.2353161 , 0.27450982],
#           [0.43137255, 0.41964364, 0.42746773, ..., 0.19679837,
#            0.2509147 , 0.28996637],
#           [0.41568682, 0.38056365, 0.41177347, ..., 0.23133881,
#            0.23138236, 0.2821337 ],
#           ...,
#           [0.42808384, 0.45884556, 0.47787955, ..., 0.5030689 ,
#            0.38849053, 0.40397757],
#           [0.38831475, 0.41095582, 0.45988405, ..., 0.26875255,
#            0.38436818, 0.40000072],
#           [0.38039216, 0.3842949 , 0.44276777, ..., 0.19764158,
#            0.36899388, 0.40392157]]], dtype=float32)),
#  (6,
#   3,
#   array([[[0.32107362, 0.23942673, 0.34034538, ..., 0.37650144,
#            0.43797478, 0.5316977 ],
#           [0.44600525, 0.37741148, 0.35755378, ..., 0.41970435,
#            0.39585853, 0.3647296 ],
#           [0.49807155, 0.4666749 , 0.452934  , ..., 0.4427362 ,
#            0.3765674 , 0.3492006 ],
#           ...,
#           [0.48631492, 0.5232898 , 0.43539798, ..., 0.5941945 ,
#            0.5063536 , 0.39292735],
#           [0.49778238, 0.5005429 , 0.46575722, ..., 0.45510244,
#            0.5212627 , 0.4118484 ],
#           [0.4589269 , 0.46676835, 0.41359302, ..., 0.46236557,
#            0.6342857 , 0.53489864]],
#
#          [[0.34068146, 0.25903457, 0.36276653, ..., 0.38042945,
#            0.43803227, 0.5316977 ],
#           [0.43833154, 0.373415  , 0.35358766, ..., 0.41968852,
#            0.39583078, 0.3647114 ],
#           [0.4824095 , 0.45493248, 0.4413774 , ..., 0.43879926,
#            0.3726715 , 0.34527904],
#           ...,
#           [0.49417302, 0.535003  , 0.4471445 , ..., 0.59042275,
#            0.51414603, 0.4121339 ],
#           [0.50162673, 0.5043054 , 0.46965888, ..., 0.4589502 ,
#            0.5368938 , 0.438544  ],
#           [0.45111668, 0.46286818, 0.41005236, ..., 0.45459256,
#            0.6383171 , 0.55040437]],
#
#          [[0.30146578, 0.21981889, 0.28811175, ..., 0.33730838,
#            0.3949829 , 0.49262092],
#           [0.40687522, 0.3341929 , 0.29879624, ..., 0.38445923,
#            0.36451378, 0.33339342],
#           [0.45887202, 0.41178077, 0.39802885, ..., 0.4191826 ,
#            0.3490952 , 0.32565004],
#           ...,
#           [0.46279514, 0.5037076 , 0.41579926, ..., 0.5825276 ,
#            0.49849498, 0.37760183],
#           [0.47820088, 0.4849361 , 0.45014024, ..., 0.4511159 ,
#            0.51734024, 0.40386766],
#           [0.44323596, 0.45498973, 0.4017158 , ..., 0.45063612,
#            0.6225397 , 0.5192726 ]]], dtype=float32)),
#  (2,
#   0,
#   array([[[0.7764706 , 0.7998619 , 0.7686414 , ..., 0.8901961 ,
#            0.8941134 , 0.90195113],
#           [0.9326802 , 0.9212954 , 0.90988034, ..., 0.89410937,
#            0.9019382 , 0.9097821 ],
#           [0.9528928 , 0.93333375, 0.92943156, ..., 0.9019638 ,
#            0.9098113 , 0.9176519 ],
#           ...,
#           [0.854682  , 0.8114691 , 0.77294636, ..., 0.8039219 ,
#            0.8117545 , 0.81567454],
#           [0.84699756, 0.8274451 , 0.8156931 , ..., 0.80784214,
#            0.80784065, 0.807849  ],
#           [0.8352664 , 0.81960785, 0.81960785, ..., 0.8039214 ,
#            0.8000005 , 0.803924  ]],
#
#          [[0.78039217, 0.8037835 , 0.772563  , ..., 0.88235295,
#            0.8862703 , 0.894108  ],
#           [0.9366018 , 0.9252169 , 0.9138019 , ..., 0.88626623,
#            0.894095  , 0.9019389 ],
#           [0.95681435, 0.93725526, 0.9333531 , ..., 0.89412063,
#            0.90196824, 0.9098088 ],
#           ...,
#           [0.85860366, 0.8153906 , 0.776868  , ..., 0.7960795 ,
#            0.80391437, 0.80783725],
#           [0.85091925, 0.83136666, 0.8196198 , ..., 0.7921579 ,
#            0.79215443, 0.7921685 ],
#           [0.839188  , 0.8235295 , 0.8235294 , ..., 0.78431374,
#            0.78431374, 0.78431857]],
#
#          [[0.7607843 , 0.7841756 , 0.75295514, ..., 0.8941136 ,
#            0.89803493, 0.9058727 ],
#           [0.91699386, 0.90560913, 0.894194  , ..., 0.89802676,
#            0.9058597 , 0.9137037 ],
#           [0.93720657, 0.9176474 , 0.9137452 , ..., 0.9058854 ,
#            0.9137329 , 0.92157346],
#           ...,
#           [0.83899575, 0.7957828 , 0.7572601 , ..., 0.8156897 ,
#            0.82744235, 0.83136374],
#           [0.83131135, 0.8117589 , 0.8000119 , ..., 0.8078452 ,
#            0.807837  , 0.8078606 ],
#           [0.81958014, 0.80392164, 0.8039216 , ..., 0.7921567 ,
#            0.7882358 , 0.79216665]]], dtype=float32)),
#  (4,
#   5,
#   array([[[0.32553062, 0.4311638 , 0.46272066, ..., 0.5460652 ,
#            0.7580801 , 0.87483543],
#           [0.3420039 , 0.4744906 , 0.4862647 , ..., 0.6802718 ,
#            0.8775269 , 0.9804016 ],
#           [0.38528427, 0.4823359 , 0.4705939 , ..., 0.82351774,
#            0.9805087 , 0.9921336 ],
#           ...,
#           [0.3685908 , 0.37871015, 0.58741593, ..., 0.63618773,
#            0.6196402 , 0.6235278 ],
#           [0.32570776, 0.42303935, 0.668971  , ..., 0.5765776 ,
#            0.6273294 , 0.6194069 ],
#           [0.38016888, 0.5443974 , 0.68950266, ..., 0.5373658 ,
#            0.5651693 , 0.5765184 ]],
#
#          [[0.32944772, 0.42334387, 0.43919942, ..., 0.502998  ,
#            0.7268484 , 0.8552637 ],
#           [0.34585232, 0.46663877, 0.46665624, ..., 0.6532779 ,
#            0.86201185, 0.97256166],
#           [0.3852071 , 0.47447616, 0.44707054, ..., 0.8002407 ,
#            0.9687985 , 0.9881966 ],
#           ...,
#           [0.32940328, 0.38357082, 0.61899096, ..., 0.61692065,
#            0.5961515 , 0.60000324],
#           [0.31380463, 0.4502884 , 0.71588236, ..., 0.56481856,
#            0.6155797 , 0.6076787 ],
#           [0.38402668, 0.57178307, 0.7325718 , ..., 0.53343195,
#            0.56119215, 0.57258815]],
#
#          [[0.2941506 , 0.38022208, 0.39215416, ..., 0.4517388 ,
#            0.62492096, 0.77683234],
#           [0.31441325, 0.42349863, 0.41959772, ..., 0.5467447 ,
#            0.7413067 , 0.8941491 ],
#           [0.35367924, 0.42741954, 0.40001172, ..., 0.6871612 ,
#            0.86335546, 0.93319577],
#           ...,
#           [0.28629515, 0.3309745 , 0.63884956, ..., 0.58189374,
#            0.5569683 , 0.56471235],
#           [0.30578348, 0.43066534, 0.7430433 , ..., 0.5373629 ,
#            0.5842304 , 0.5802643 ],
#           [0.39571166, 0.579582  , 0.7560328 , ..., 0.51381195,
#            0.5415012 , 0.55297166]]], dtype=float32)),
#  (5,
#   3,
#   array([[[0.53340214, 0.557124  , 0.5827936 , ..., 0.66164875,
#            0.59270185, 0.33325502],
#           [0.5529072 , 0.52966374, 0.5580316 , ..., 0.6770661 ,
#            0.6036898 , 0.3399009 ],
#           [0.5607834 , 0.4977327 , 0.53398025, ..., 0.68590885,
#            0.61517036, 0.33331972],
#           ...,
#           [0.5762959 , 0.5761256 , 0.58432174, ..., 0.5644189 ,
#            0.5680289 , 0.5294212 ],
#           [0.5294548 , 0.5445693 , 0.5564891 , ..., 0.548888  ,
#            0.54564506, 0.5411948 ],
#           [0.45882353, 0.47432443, 0.5051086 , ..., 0.51800644,
#            0.518489  , 0.52560854]],
#
#          [[0.5255728 , 0.5532771 , 0.5863655 , ..., 0.6657899 ,
#            0.60330987, 0.35609427],
#           [0.5489992 , 0.53727996, 0.56346184, ..., 0.6853134 ,
#            0.62094486, 0.3669158 ],
#           [0.5568628 , 0.5092885 , 0.5451657 , ..., 0.6977661 ,
#            0.63372207, 0.3607707 ],
#           ...,
#           [0.6745567 , 0.65915745, 0.64335257, ..., 0.76068586,
#            0.76828235, 0.7411577 ],
#           [0.6901826 , 0.690223  , 0.70976424, ..., 0.77241355,
#            0.7648568 , 0.7569014 ],
#           [0.68235296, 0.6939786 , 0.7133386 , ..., 0.7415144 ,
#            0.7303363 , 0.7257267 ]],
#
#          [[0.4628552 , 0.49434155, 0.51624787, ..., 0.59050417,
#            0.5020743 , 0.26863238],
#           [0.49408063, 0.47075242, 0.48800007, ..., 0.5945839 ,
#            0.50262374, 0.26735887],
#           [0.49803922, 0.42732725, 0.45633328, ..., 0.6034588 ,
#            0.51593596, 0.26664624],
#           ...,
#           [0.34492618, 0.34855837, 0.3685933 , ..., 0.35255942,
#            0.3364956 , 0.27850646],
#           [0.29808098, 0.30540103, 0.32110515, ..., 0.3409857 ,
#            0.3258838 , 0.30988115],
#           [0.24313726, 0.23926203, 0.25804976, ..., 0.29852176,
#            0.2991854 , 0.33315593]]], dtype=float32)),
#  (5,
#   2,
#   array([[[0.6392152 , 0.62744325, 0.62353414, ..., 0.32124782,
#            0.49018568, 0.656338  ],
#           [0.6352784 , 0.615714  , 0.6196542 , ..., 0.1657669 ,
#            0.39467353, 0.6511968 ],
#           [0.6431331 , 0.6313726 , 0.6314393 , ..., 0.18792735,
#            0.46359318, 0.69495183],
#           ...,
#           [0.8078297 , 0.7764197 , 0.7958988 , ..., 0.7961005 ,
#            0.82715356, 0.7844508 ],
#           [0.76078457, 0.74525076, 0.76871157, ..., 0.80000126,
#            0.8351624 , 0.7960782 ],
#           [0.76078564, 0.768593  , 0.7803729 , ..., 0.8235497 ,
#            0.8352896 , 0.7921569 ]],
#
#          [[0.5019602 , 0.4901906 , 0.48628157, ..., 0.25489458,
#            0.40849245, 0.54308593],
#           [0.49802688, 0.48237243, 0.48632938, ..., 0.14179088,
#            0.3504133 , 0.5648436 ],
#           [0.50588024, 0.49804065, 0.49812698, ..., 0.15682645,
#            0.3919532 , 0.59303486],
#           ...,
#           [0.7372011 , 0.6979648 , 0.70571   , ..., 0.686186  ,
#            0.72511506, 0.6785834 ],
#           [0.69018346, 0.6668361 , 0.6785143 , ..., 0.6901921 ,
#            0.73317236, 0.6941175 ],
#           [0.6901955 , 0.68624526, 0.68625635, ..., 0.7098444 ,
#            0.7333243 , 0.6901961 ]],
#
#          [[0.38823497, 0.3803867 , 0.37647763, ..., 0.18447773,
#            0.33425024, 0.4454018 ],
#           [0.38822144, 0.37256852, 0.37652546, ..., 0.1061311 ,
#            0.29480657, 0.47862807],
#           [0.39607632, 0.38823673, 0.38832307, ..., 0.14078832,
#            0.34387028, 0.5184373 ],
#           ...,
#           [0.62743753, 0.5960186 , 0.6037971 , ..., 0.5959843 ,
#            0.634919  , 0.5883873 ],
#           [0.58822477, 0.5687736 , 0.58437383, ..., 0.599996  ,
#            0.6429762 , 0.6039214 ],
#           [0.59999514, 0.59995353, 0.60389054, ..., 0.6196484 ,
#            0.6431282 , 0.6       ]]], dtype=float32)),
#  (0,
#   3,
#   array([[[0.55294156, 0.5568635 , 0.56078583, ..., 0.47843274,
#            0.48234725, 0.45888272],
#           [0.54119915, 0.5529    , 0.5257539 , ..., 0.47067004,
#            0.47061235, 0.43554425],
#           [0.5333297 , 0.54508924, 0.51813847, ..., 0.4941639 ,
#            0.45071524, 0.41573393],
#           ...,
#           [0.9960784 , 0.9920156 , 0.99517685, ..., 0.99981874,
#            1.        , 1.        ],
#           [0.9921575 , 0.9882438 , 0.9999897 , ..., 0.99606526,
#            0.9999999 , 1.        ],
#           [0.9921547 , 0.98431647, 0.98824733, ..., 0.9882353 ,
#            0.98823917, 0.9882396 ]],
#
#          [[0.5607847 , 0.56470656, 0.56862855, ..., 0.48627573,
#            0.4901904 , 0.46672586],
#           [0.5490423 , 0.56074315, 0.53359705, ..., 0.47852683,
#            0.47845548, 0.4433874 ],
#           [0.54117286, 0.5529324 , 0.5259816 , ..., 0.50591826,
#            0.46247992, 0.42749575],
#           ...,
#           [1.        , 0.99198467, 0.9871402 , ..., 0.9919359 ,
#            0.9921596 , 0.98825127],
#           [1.        , 0.99999046, 0.99998575, ..., 0.99606514,
#            0.9960778 , 0.9960739 ],
#           [0.99999577, 0.9843235 , 0.98824733, ..., 0.9882353 ,
#            0.98823786, 0.98823816]],
#
#          [[0.6117651 , 0.615687  , 0.6196087 , ..., 0.58039266,
#            0.5843081 , 0.56475526],
#           [0.60002255, 0.61172354, 0.58457744, ..., 0.5608678 ,
#            0.5647321 , 0.52969533],
#           [0.5921533 , 0.6039128 , 0.576962  , ..., 0.58433574,
#            0.54087114, 0.505933  ],
#           ...,
#           [1.        , 0.97630066, 0.96753883, ..., 0.99975526,
#            0.99608207, 0.98042357],
#           [1.        , 0.9921366 , 0.9882135 , ..., 0.9999803 ,
#            0.9999993 , 0.9921526 ],
#           [0.99607545, 0.9843188 , 0.9882352 , ..., 0.9882353 ,
#            0.98823917, 0.9882367 ]]], dtype=float32)),
#  (3,
#   7,
#   array([[[0.05098039, 0.04705946, 0.0509797 , ..., 0.12156732,
#            0.12157058, 0.11764706],
#           [0.05881662, 0.05490168, 0.05882327, ..., 0.12156229,
#            0.12937512, 0.12549342],
#           [0.05098143, 0.05099077, 0.05883513, ..., 0.09793555,
#            0.12157268, 0.1254902 ],
#           ...,
#           [0.5921569 , 0.60769075, 0.6640358 , ..., 0.5019628 ,
#            0.49022642, 0.47845358],
#           [0.5961558 , 0.6178085 , 0.69127274, ..., 0.5019661 ,
#            0.49020368, 0.47844186],
#           [0.5805648 , 0.6008015 , 0.6631929 , ..., 0.49412763,
#            0.47847047, 0.46672717]],
#
#          [[0.03529412, 0.03529412, 0.03137324, ..., 0.09411678,
#            0.09019836, 0.08627451],
#           [0.03136971, 0.03528954, 0.03529311, ..., 0.09019157,
#            0.09409934, 0.09020101],
#           [0.02745208, 0.03137774, 0.03529412, ..., 0.066563  ,
#            0.08628039, 0.09411547],
#           ...,
#           [0.5254902 , 0.5487851 , 0.6331759 , ..., 0.43529606,
#            0.42747045, 0.4157067 ],
#           [0.5295237 , 0.55995464, 0.6664866 , ..., 0.43529943,
#            0.42353952, 0.41177875],
#           [0.51394546, 0.5422646 , 0.62800455, ..., 0.4196278 ,
#            0.41179267, 0.4000605 ]],
#
#          [[0.03137255, 0.02745162, 0.02745098, ..., 0.06666624,
#            0.06666667, 0.06666667],
#           [0.02352292, 0.02352698, 0.02745098, ..., 0.06666214,
#            0.06666667, 0.06274832],
#           [0.01568789, 0.01961303, 0.02353663, ..., 0.04701199,
#            0.05882759, 0.0627451 ],
#           ...,
#           [0.42745063, 0.4662708 , 0.58574426, ..., 0.32549214,
#            0.32157952, 0.31373972],
#           [0.43544894, 0.4785723 , 0.61820537, ..., 0.32549554,
#            0.31765467, 0.30981445],
#           [0.41987523, 0.45638138, 0.5732394 , ..., 0.31765705,
#            0.30982628, 0.30200115]]], dtype=float32)),
#  (2,
#   5,
#   array([[[0.25882354, 0.25098252, 0.25108942, ..., 0.19215207,
#            0.1882449 , 0.20385952],
#           [0.25490695, 0.25490198, 0.2588985 , ..., 0.19605023,
#            0.18823764, 0.20000798],
#           [0.27469566, 0.25491598, 0.26269868, ..., 0.19604206,
#            0.18043381, 0.18822856],
#           ...,
#           [0.29019392, 0.39286792, 0.66310656, ..., 0.26273382,
#            0.25497833, 0.2785234 ],
#           [0.2788541 , 0.3935685 , 0.66410655, ..., 0.263131  ,
#            0.22373767, 0.24706008],
#           [0.27527252, 0.3781553 , 0.65219504, ..., 0.25959313,
#            0.20800222, 0.2468887 ]],
#
#          [[0.1764706 , 0.16862957, 0.17265801, ..., 0.13333334,
#            0.13333334, 0.14504403],
#           [0.1764706 , 0.1725505 , 0.18046708, ..., 0.13331924,
#            0.12941939, 0.13727085],
#           [0.19629526, 0.17256999, 0.18424495, ..., 0.13333231,
#            0.12941992, 0.1255047 ],
#           ...,
#           [0.2039194 , 0.32013416, 0.6195844 , ..., 0.16862746,
#            0.16862375, 0.17656256],
#           [0.19264223, 0.32281697, 0.6211503 , ..., 0.16503096,
#            0.13351098, 0.1450993 ],
#           [0.18519852, 0.30313566, 0.60921854, ..., 0.16540241,
#            0.1177939 , 0.14497894]],
#
#          [[0.14901961, 0.15686063, 0.14905286, ..., 0.11765803,
#            0.125471  , 0.13329339],
#           [0.1411864 , 0.1529368 , 0.14905623, ..., 0.11767524,
#            0.1254685 , 0.12550615],
#           [0.15701763, 0.1529342 , 0.14904197, ..., 0.11766962,
#            0.12156499, 0.11374708],
#           ...,
#           [0.14509659, 0.24471416, 0.52957994, ..., 0.12941489,
#            0.12942035, 0.14117648],
#           [0.13767588, 0.25424343, 0.53883535, ..., 0.12577245,
#            0.10213914, 0.12156941],
#           [0.13801564, 0.24240334, 0.530784  , ..., 0.12212924,
#            0.09029397, 0.12533592]]], dtype=float32)),
#  (0,
#   1,
#   array([[[0.04313406, 0.0784156 , 0.08241167, ..., 0.9725298 ,
#            0.9607885 , 0.9647059 ],
#           [0.02745182, 0.07464433, 0.12927414, ..., 0.96083283,
#            0.98424584, 0.98038083],
#           [0.03537139, 0.14871825, 0.2666805 , ..., 0.59001905,
#            0.8082974 , 0.9373597 ],
#           ...,
#           [0.40052012, 0.5650267 , 0.68633825, ..., 0.607795  ,
#            0.65849096, 0.681724  ],
#           [0.3963304 , 0.54548925, 0.6785435 , ..., 0.5220118 ,
#            0.7017054 , 0.66282725],
#           [0.41189718, 0.5218259 , 0.66670775, ..., 0.23189591,
#            0.4090045 , 0.6040477 ]],
#
#          [[0.05488446, 0.0392179 , 0.03923344, ..., 0.9725362 ,
#            0.9647142 , 0.972549  ],
#           [0.03137339, 0.01577145, 0.05091434, ..., 0.9960567 ,
#            0.99990195, 0.99606144],
#           [0.03928889, 0.06264556, 0.13720116, ..., 0.6213832 ,
#            0.83180267, 0.95304596],
#           ...,
#           [0.0553885 , 0.20440695, 0.35719466, ..., 0.5765191 ,
#            0.65838355, 0.6776412 ],
#           [0.05900525, 0.17691715, 0.32572412, ..., 0.46721575,
#            0.67828876, 0.6471903 ],
#           [0.09807277, 0.1492749 , 0.28645775, ..., 0.16916777,
#            0.37375686, 0.57662195]],
#
#          [[0.03528925, 0.03529263, 0.03925233, ..., 0.9882225 ,
#            0.9803963 , 0.9843137 ],
#           [0.02745225, 0.02756189, 0.06657583, ..., 0.9999862 ,
#            0.99994975, 0.9999887 ],
#           [0.0393011 , 0.09002649, 0.1803781 , ..., 0.62921363,
#            0.8396363 , 0.96087956],
#           ...,
#           [0.09479788, 0.30614218, 0.4352973 , ..., 0.5879514 ,
#            0.63076484, 0.6383449 ],
#           [0.08657439, 0.25928178, 0.40013117, ..., 0.43208048,
#            0.64302707, 0.6118797 ],
#           [0.12950975, 0.23161682, 0.36087418, ..., 0.13387413,
#            0.34235078, 0.5256752 ]]], dtype=float32)),
#  (8,
#   0,
#   array([[[0.67450595, 0.6705914 , 0.67843026, ..., 0.7450868 ,
#            0.74117935, 0.7450971 ],
#           [0.67450804, 0.67061573, 0.68239516, ..., 0.74115413,
#            0.7450973 , 0.7411783 ],
#           [0.6901795 , 0.69014764, 0.6979133 , ..., 0.7372399 ,
#            0.74509746, 0.7450957 ],
#           ...,
#           [0.25888103, 0.2631159 , 0.27154627, ..., 0.35276568,
#            0.35979518, 0.30254534],
#           [0.28586867, 0.2897523 , 0.28617305, ..., 0.45797104,
#            0.49425775, 0.46303427],
#           [0.23529412, 0.24380575, 0.23468448, ..., 0.494443  ,
#            0.5215153 , 0.5132147 ]],
#
#          [[0.7019471 , 0.6980424 , 0.70588124, ..., 0.7411714 ,
#            0.7372577 , 0.7411756 ],
#           [0.69413024, 0.6941544 , 0.7019787 , ..., 0.7411174 ,
#            0.74117994, 0.7372585 ],
#           [0.7019525 , 0.70194143, 0.7097262 , ..., 0.73333424,
#            0.7450899 , 0.7450933 ],
#           ...,
#           [0.25495946, 0.25913057, 0.2676453 , ..., 0.31629348,
#            0.3278396 , 0.28261784],
#           [0.28194708, 0.28583077, 0.2823149 , ..., 0.41123083,
#            0.4587665 , 0.43942896],
#           [0.23137255, 0.2398842 , 0.23086448, ..., 0.43963403,
#            0.4744441 , 0.47802275]],
#
#          [[0.7921246 , 0.7843201 , 0.7921558 , ..., 0.7686099 ,
#            0.7647056 , 0.7686249 ],
#           [0.7725786 , 0.76871943, 0.77645266, ..., 0.76062953,
#            0.76077396, 0.75685924],
#           [0.76079524, 0.75689554, 0.7686316 , ..., 0.74114513,
#            0.74904096, 0.74902433],
#           ...,
#           [0.2745673 , 0.27873844, 0.28724617, ..., 0.25982702,
#            0.27869523, 0.24257725],
#           [0.30155492, 0.30543858, 0.3018806 , ..., 0.34042355,
#            0.39579582, 0.3844416 ],
#           [0.2509804 , 0.25949204, 0.25043643, ..., 0.34957737,
#            0.3959938 , 0.4075832 ]]], dtype=float32)),
#  (2,
#   4,
#   array([[[0.6706658 , 0.64760447, 0.64434266, ..., 0.8380795 ,
#            0.88563764, 0.9529412 ],
#           [0.68638206, 0.67866087, 0.6902173 , ..., 0.6667387 ,
#            0.7085941 , 0.7508568 ],
#           [0.7019356 , 0.6936445 , 0.6978723 , ..., 0.6175036 ,
#            0.6171806 , 0.62349   ],
#           ...,
#           [0.6548639 , 0.63328886, 0.62504137, ..., 0.6377348 ,
#            0.5881694 , 0.57653725],
#           [0.650992  , 0.5451696 , 0.54987717, ..., 0.6261807 ,
#            0.5811043 , 0.6187035 ],
#           [0.63018984, 0.5769305 , 0.6040458 , ..., 0.6159517 ,
#            0.6332419 , 0.65059596]],
#
#          [[0.78435254, 0.7650384 , 0.757778  , ..., 0.8535126 ,
#            0.8958852 , 0.9490196 ],
#           [0.79218376, 0.7844446 , 0.7921533 , ..., 0.724568  ,
#            0.75566256, 0.7866304 ],
#           [0.79604214, 0.79147696, 0.79192907, ..., 0.6951781 ,
#            0.69506085, 0.7058388 ],
#           ...,
#           [0.67439544, 0.6525128 , 0.6433861 , ..., 0.6341213 ,
#            0.6038191 , 0.59612733],
#           [0.66277987, 0.55694765, 0.5628301 , ..., 0.6165861 ,
#            0.58886635, 0.6304961 ],
#           [0.62234676, 0.56943417, 0.5962027 , ..., 0.58865994,
#            0.61065376, 0.642825  ]],
#
#          [[0.39223439, 0.36143014, 0.37753075, ..., 0.74940276,
#            0.8223845 , 0.92156863],
#           [0.40797752, 0.39643902, 0.41963696, ..., 0.49991068,
#            0.57534224, 0.6545286 ],
#           [0.42742103, 0.41514713, 0.43119287, ..., 0.37728453,
#            0.39506984, 0.4037186 ],
#           ...,
#           [0.40007627, 0.38597292, 0.37419522, ..., 0.42902005,
#            0.37644902, 0.37652835],
#           [0.40781996, 0.3059028 , 0.30561984, ..., 0.41417238,
#            0.3731342 , 0.41477048],
#           [0.39890176, 0.34920013, 0.3766155 , ..., 0.4119869 ,
#            0.42919195, 0.43895218]]], dtype=float32)),
#  (0,
#   9,
#   array([[[0.63529414, 0.6431373 , 0.654902  , ..., 0.654902  ,
#            0.654902  , 0.6666667 ],
#           [0.62352943, 0.6313726 , 0.6392157 , ..., 0.6627451 ,
#            0.6627451 , 0.6627451 ],
#           [0.61960787, 0.6156863 , 0.62352943, ..., 0.6666667 ,
#            0.6627451 , 0.67058825],
#           ...,
#           [0.4392157 , 0.4627451 , 0.45490196, ..., 0.45882353,
#            0.4627451 , 0.48235294],
#           [0.47843137, 0.48235294, 0.49019608, ..., 0.5019608 ,
#            0.48235294, 0.47843137],
#           [0.57254905, 0.48235294, 0.49803922, ..., 0.47843137,
#            0.4627451 , 0.4509804 ]],
#
#          [[0.7490196 , 0.7529412 , 0.7647059 , ..., 0.8156863 ,
#            0.8156863 , 0.827451  ],
#           [0.73333335, 0.7411765 , 0.7490196 , ..., 0.827451  ,
#            0.8235294 , 0.827451  ],
#           [0.73333335, 0.7254902 , 0.73333335, ..., 0.83137256,
#            0.827451  , 0.8352941 ],
#           ...,
#           [0.45882353, 0.45882353, 0.47058824, ..., 0.42745098,
#            0.42745098, 0.44705883],
#           [0.5019608 , 0.4745098 , 0.49411765, ..., 0.47843137,
#            0.4509804 , 0.44705883],
#           [0.6039216 , 0.47058824, 0.48235294, ..., 0.45882353,
#            0.44705883, 0.43529412]],
#
#          [[0.8352941 , 0.8392157 , 0.84705883, ..., 0.9254902 ,
#            0.9254902 , 0.9411765 ],
#           [0.81960785, 0.827451  , 0.8352941 , ..., 0.92941177,
#            0.9254902 , 0.93333334],
#           [0.81960785, 0.8117647 , 0.8156863 , ..., 0.92941177,
#            0.91764706, 0.92941177],
#           ...,
#           [0.34117648, 0.32941177, 0.34901962, ..., 0.3137255 ,
#            0.3137255 , 0.32941177],
#           [0.4       , 0.34901962, 0.37254903, ..., 0.3647059 ,
#            0.3372549 , 0.33333334],
#           [0.5176471 , 0.3529412 , 0.3647059 , ..., 0.34117648,
#            0.32941177, 0.3137255 ]]], dtype=float32)),
#  (2,
#   0,
#   array([[[0.67058825, 0.6901961 , 0.7019608 , ..., 0.48235294,
#            0.46666667, 0.45490196],
#           [0.70980394, 0.7176471 , 0.7176471 , ..., 0.48235294,
#            0.5176471 , 0.5372549 ],
#           [0.7490196 , 0.74509805, 0.7490196 , ..., 0.47058824,
#            0.49803922, 0.44705883],
#           ...,
#           [0.627451  , 0.6156863 , 0.61960787, ..., 0.6431373 ,
#            0.6392157 , 0.6392157 ],
#           [0.63529414, 0.61960787, 0.62352943, ..., 0.654902  ,
#            0.6392157 , 0.6313726 ],
#           [0.6392157 , 0.63529414, 0.6313726 , ..., 0.67058825,
#            0.65882355, 0.64705884]],
#
#          [[0.74509805, 0.7607843 , 0.7764706 , ..., 0.49019608,
#            0.47843137, 0.47058824],
#           [0.78039217, 0.7882353 , 0.7882353 , ..., 0.49019608,
#            0.52156866, 0.53333336],
#           [0.81960785, 0.8156863 , 0.81960785, ..., 0.47843137,
#            0.5058824 , 0.45490196],
#           ...,
#           [0.7058824 , 0.69411767, 0.7019608 , ..., 0.7137255 ,
#            0.70980394, 0.72156864],
#           [0.70980394, 0.69411767, 0.69411767, ..., 0.7254902 ,
#            0.7137255 , 0.7137255 ],
#           [0.7137255 , 0.70980394, 0.7058824 , ..., 0.7411765 ,
#            0.73333335, 0.7294118 ]],
#
#          [[0.7921569 , 0.80784315, 0.8235294 , ..., 0.43529412,
#            0.41960785, 0.41568628],
#           [0.827451  , 0.8352941 , 0.8352941 , ..., 0.43529412,
#            0.46666667, 0.47843137],
#           [0.8666667 , 0.8627451 , 0.8666667 , ..., 0.42352942,
#            0.4509804 , 0.3882353 ],
#           ...,
#           [0.73333335, 0.72156864, 0.7254902 , ..., 0.7607843 ,
#            0.75686276, 0.7647059 ],
#           [0.7372549 , 0.72156864, 0.72156864, ..., 0.77254903,
#            0.75686276, 0.75686276],
#           [0.74509805, 0.7372549 , 0.73333335, ..., 0.7882353 ,
#            0.78039217, 0.77254903]]], dtype=float32)),
#  (2,
#   4,
#   array([[[0.7058824 , 0.52156866, 0.46666667, ..., 0.27058825,
#            0.27450982, 0.54901963],
#           [0.50980395, 0.49803922, 0.40392157, ..., 0.1764706 ,
#            0.18039216, 0.19607843],
#           [0.45490196, 0.4392157 , 0.37254903, ..., 0.19215687,
#            0.20784314, 0.1882353 ],
#           ...,
#           [0.69803923, 0.7137255 , 0.69803923, ..., 0.7058824 ,
#            0.6666667 , 0.6156863 ],
#           [0.7529412 , 0.7294118 , 0.7607843 , ..., 0.6392157 ,
#            0.6392157 , 0.6392157 ],
#           [0.7882353 , 0.7372549 , 0.7372549 , ..., 0.5803922 ,
#            0.54901963, 0.6901961 ]],
#
#          [[0.6901961 , 0.49411765, 0.45490196, ..., 0.27058825,
#            0.27450982, 0.5529412 ],
#           [0.49411765, 0.48235294, 0.40784314, ..., 0.16470589,
#            0.16862746, 0.19607843],
#           [0.4392157 , 0.42745098, 0.3882353 , ..., 0.16470589,
#            0.18039216, 0.18039216],
#           ...,
#           [0.62352943, 0.6156863 , 0.6       , ..., 0.63529414,
#            0.59607846, 0.57254905],
#           [0.7019608 , 0.6509804 , 0.68235296, ..., 0.6       ,
#            0.6       , 0.6156863 ],
#           [0.7647059 , 0.6862745 , 0.68235296, ..., 0.57254905,
#            0.5411765 , 0.68235296]],
#
#          [[0.64705884, 0.4117647 , 0.37254903, ..., 0.25882354,
#            0.26666668, 0.54509807],
#           [0.4       , 0.34509805, 0.27450982, ..., 0.15686275,
#            0.16470589, 0.18431373],
#           [0.33333334, 0.27450982, 0.23137255, ..., 0.16470589,
#            0.18039216, 0.16078432],
#           ...,
#           [0.6117647 , 0.5921569 , 0.5882353 , ..., 0.5686275 ,
#            0.53333336, 0.54509807],
#           [0.69411767, 0.6313726 , 0.67058825, ..., 0.47843137,
#            0.48235294, 0.5686275 ],
#           [0.7529412 , 0.67058825, 0.6745098 , ..., 0.4745098 ,
#            0.45490196, 0.6392157 ]]], dtype=float32)),
#  (1,
#   8,
#   array([[[0.9999891 , 0.99600077, 0.9803382 , ..., 0.99999434,
#            0.9960786 , 0.96864134],
#           [0.9803933 , 0.9882135 , 0.9800602 , ..., 0.9960908 ,
#            0.99214715, 0.9765072 ],
#           [0.9803934 , 0.9838347 , 0.9685229 , ..., 0.9999965 ,
#            0.99997973, 0.9921816 ],
#           ...,
#           [0.37675732, 0.37254655, 0.3686132 , ..., 0.35301334,
#            0.34132096, 0.32548714],
#           [0.34512472, 0.3569006 , 0.37256002, ..., 0.3527705 ,
#            0.3255716 , 0.31767747],
#           [0.345134  , 0.36077324, 0.37646955, ..., 0.3529306 ,
#            0.34120363, 0.32547522]],
#
#          [[0.9999891 , 0.99600077, 0.9803382 , ..., 0.99998873,
#            0.99999505, 0.9960715 ],
#           [0.9803933 , 0.9882135 , 0.9800602 , ..., 0.9921852 ,
#            0.9960807 , 0.99217236],
#           [0.9803934 , 0.9838347 , 0.9685229 , ..., 0.999993  ,
#            0.999996  , 0.99999225],
#           ...,
#           [0.4551477 , 0.45098   , 0.44701833, ..., 0.4510204 ,
#            0.44323355, 0.44313574],
#           [0.43532348, 0.4470728 , 0.46275368, ..., 0.45478663,
#            0.4392365 , 0.4392309 ],
#           [0.44316423, 0.4548915 , 0.4744949 , ..., 0.466657  ,
#            0.45884165, 0.45487198]],
#
#          [[0.9999891 , 0.99600077, 0.9803382 , ..., 0.9960784 ,
#            0.99999   , 0.9999861 ],
#           [0.9803933 , 0.9882135 , 0.9800602 , ..., 0.99607843,
#            0.99608076, 0.99215966],
#           [0.9803934 , 0.9838347 , 0.9685491 , ..., 0.9999965 ,
#            0.9999797 , 0.99215066],
#           ...,
#           [0.4747965 , 0.47058713, 0.47050333, ..., 0.46279708,
#            0.4589283 , 0.45097885],
#           [0.45100975, 0.46276703, 0.47844407, ..., 0.4704309 ,
#            0.45102113, 0.44707403],
#           [0.4588505 , 0.4705778 , 0.49018455, ..., 0.47839323,
#            0.47060636, 0.46271512]]], dtype=float32)),
#  (2,
#   4,
#   array([[[0.45882353, 0.49019608, 0.39607844, ..., 0.45490196,
#            0.4392157 , 0.42352942],
#           [0.4627451 , 0.4509804 , 0.42745098, ..., 0.4509804 ,
#            0.4627451 , 0.4117647 ],
#           [0.47058824, 0.43529412, 0.49019608, ..., 0.42745098,
#            0.4117647 , 0.39607844],
#           ...,
#           [0.5764706 , 0.5568628 , 0.5764706 , ..., 0.4117647 ,
#            0.3764706 , 0.34509805],
#           [0.5686275 , 0.54509807, 0.54509807, ..., 0.15686275,
#            0.16078432, 0.29411766],
#           [0.5372549 , 0.5647059 , 0.57254905, ..., 0.15294118,
#            0.18039216, 0.28235295]],
#
#          [[0.49411765, 0.5254902 , 0.4392157 , ..., 0.5058824 ,
#            0.49411765, 0.48235294],
#           [0.49019608, 0.4862745 , 0.46666667, ..., 0.49411765,
#            0.49803922, 0.4509804 ],
#           [0.5019608 , 0.47058824, 0.5254902 , ..., 0.47843137,
#            0.4627451 , 0.4509804 ],
#           ...,
#           [0.5921569 , 0.57254905, 0.59607846, ..., 0.41960785,
#            0.38039216, 0.32941177],
#           [0.58431375, 0.56078434, 0.56078434, ..., 0.16470589,
#            0.16078432, 0.27058825],
#           [0.5568628 , 0.57254905, 0.5803922 , ..., 0.14901961,
#            0.16862746, 0.25882354]],
#
#          [[0.5019608 , 0.54509807, 0.47843137, ..., 0.5529412 ,
#            0.54901963, 0.54509807],
#           [0.5176471 , 0.5176471 , 0.5019608 , ..., 0.53333336,
#            0.54509807, 0.5058824 ],
#           [0.5254902 , 0.49411765, 0.53333336, ..., 0.5254902 ,
#            0.52156866, 0.5019608 ],
#           ...,
#           [0.5921569 , 0.58431375, 0.6039216 , ..., 0.4       ,
#            0.36078432, 0.2901961 ],
#           [0.58431375, 0.5686275 , 0.5647059 , ..., 0.14509805,
#            0.14117648, 0.22745098],
#           [0.5529412 , 0.5764706 , 0.5803922 , ..., 0.12941177,
#            0.14117648, 0.20784314]]], dtype=float32)),
#  (2,
#   8,
#   array([[[2.03754798e-01, 2.67724872e-01, 5.52825868e-01, ...,
#            1.17647061e-02, 1.17635829e-02, 1.17618088e-02],
#           [1.48998335e-01, 1.93063319e-01, 3.47147018e-01, ...,
#            1.17686894e-02, 7.84554984e-03, 7.84313772e-03],
#           [1.29414096e-01, 1.69448987e-01, 2.52932042e-01, ...,
#            1.17647052e-02, 1.17647061e-02, 7.84313772e-03],
#           ...,
#           [9.00129899e-02, 4.32251357e-02, 6.30370006e-02, ...,
#            7.57800043e-02, 1.60889775e-01, 1.80430502e-01],
#           [1.01824865e-01, 8.22781697e-02, 6.44485131e-02, ...,
#            6.03085160e-02, 1.13727286e-01, 1.17751203e-01],
#           [1.41017675e-01, 1.60654619e-01, 9.86097902e-02, ...,
#            1.33318439e-01, 1.13727473e-01, 1.33333340e-01]],
#
#          [[1.56731695e-01, 1.96281761e-01, 4.62255388e-01, ...,
#            1.56862456e-02, 1.17635904e-02, 1.17618088e-02],
#           [1.13712728e-01, 1.29543439e-01, 2.58310676e-01, ...,
#            1.17723010e-02, 7.84554984e-03, 7.84313772e-03],
#           [1.01962179e-01, 1.14256993e-01, 1.67426184e-01, ...,
#            1.56862754e-02, 1.17651997e-02, 7.84313772e-03],
#           ...,
#           [1.17420912e-01, 7.82764778e-02, 4.71640974e-02, ...,
#            7.17384890e-02, 1.49090260e-01, 1.68627456e-01],
#           [8.26062188e-02, 7.45240226e-02, 4.86142337e-02, ...,
#            6.02790751e-02, 1.09805718e-01, 1.13829635e-01],
#           [1.29221216e-01, 1.41098648e-01, 8.67737532e-02, ...,
#            1.33328378e-01, 1.09805904e-01, 1.29411772e-01]],
#
#          [[8.61672908e-02, 1.08981416e-01, 3.52326691e-01, ...,
#            2.99191960e-08, 3.92043823e-03, 3.91867151e-03],
#           [5.09803928e-02, 5.04441075e-02, 1.57522842e-01, ...,
#            3.60813601e-06, 2.41176758e-06, 0.00000000e+00],
#           [5.09803928e-02, 3.95230539e-02, 6.99620247e-02, ...,
#            3.92041681e-03, 3.92156886e-03, 0.00000000e+00],
#           ...,
#           [9.39909220e-02, 7.04551339e-02, 2.35766396e-02, ...,
#            2.83188615e-02, 8.63519087e-02, 1.01979956e-01],
#           [7.85428435e-02, 7.45036900e-02, 4.06230912e-02, ...,
#            2.91028097e-02, 5.89177161e-02, 6.31096214e-02],
#           [1.29205331e-01, 1.37203023e-01, 8.28521922e-02, ...,
#            1.25485227e-01, 1.01962373e-01, 1.17647059e-01]]], dtype=float32)),
#  (4,
#   2,
#   array([[[0.19215705, 0.19607836, 0.18431461, ..., 0.23921192,
#            0.37253606, 0.5058824 ],
#           [0.20392242, 0.19608   , 0.20000415, ..., 0.26271614,
#            0.40390384, 0.48628408],
#           [0.22745039, 0.22352871, 0.22744896, ..., 0.36077785,
#            0.44709137, 0.5411463 ],
#           ...,
#           [0.7411747 , 0.75686234, 0.7257044 , ..., 0.7333296 ,
#            0.70932466, 0.45906517],
#           [0.7725468 , 0.7607884 , 0.8117748 , ..., 0.6235228 ,
#            0.5450487 , 0.41970187],
#           [0.7999998 , 0.79607695, 0.8470585 , ..., 0.5490102 ,
#            0.46664852, 0.36864904]],
#
#          [[0.34117666, 0.345098  , 0.3333345 , ..., 0.32940987,
#            0.39999312, 0.45882353],
#           [0.35294202, 0.3450996 , 0.34902433, ..., 0.34116894,
#            0.42351875, 0.45883584],
#           [0.37647   , 0.37254828, 0.37646857, ..., 0.4274454 ,
#            0.4510066 , 0.52937293],
#           ...,
#           [0.8196064 , 0.8470581 , 0.7962355 , ..., 0.78431034,
#            0.7603431 , 0.5257186 ],
#           [0.85882056, 0.83922535, 0.8666703 , ..., 0.686269  ,
#            0.6156401 , 0.49420714],
#           [0.86274505, 0.84314007, 0.8745091 , ..., 0.627442  ,
#            0.5490015 , 0.4510013 ]],
#
#          [[0.4156865 , 0.4196078 , 0.40784445, ..., 0.31764707,
#            0.32548946, 0.28235295],
#           [0.43137327, 0.41960943, 0.4235341 , ..., 0.30982092,
#            0.26275408, 0.22746123],
#           [0.4509798 , 0.44705814, 0.44705713, ..., 0.36470044,
#            0.22747056, 0.28624216],
#           ...,
#           [0.51764566, 0.52549016, 0.5217941 , ..., 0.49019253,
#            0.48974463, 0.25512376],
#           [0.53333235, 0.5294126 , 0.61177546, ..., 0.38038722,
#            0.33329606, 0.24320087],
#           [0.54901946, 0.57254285, 0.6666654 , ..., 0.309799  ,
#            0.26665726, 0.21569759]]], dtype=float32)),
#  (2,
#   6,
#   array([[[0.4862745 , 0.50764537, 0.5881847 , ..., 0.56053895,
#            0.5256839 , 0.50196445],
#           [0.4862745 , 0.49841833, 0.53014594, ..., 0.49491337,
#            0.4790699 , 0.52862227],
#           [0.4784314 , 0.47813523, 0.45154524, ..., 0.5147427 ,
#            0.584508  , 0.5801403 ],
#           ...,
#           [0.38040987, 0.38278916, 0.4919164 , ..., 0.4293731 ,
#            0.46679407, 0.5019255 ],
#           [0.355994  , 0.32786128, 0.37804294, ..., 0.46652454,
#            0.4667414 , 0.48658758],
#           [0.32156864, 0.39139393, 0.31425753, ..., 0.4742272 ,
#            0.4393    , 0.42818683]],
#
#          [[0.63137364, 0.63663733, 0.69800067, ..., 0.67415285,
#            0.6277092 , 0.5921623 ],
#           [0.6352836 , 0.6238308 , 0.6399312 , ..., 0.6045034 ,
#            0.57722044, 0.6189035 ],
#           [0.623487  , 0.6033631 , 0.5621475 , ..., 0.61655754,
#            0.6825342 , 0.6742385 ],
#           ...,
#           [0.4039275 , 0.42902145, 0.57270515, ..., 0.499816  ,
#            0.52167165, 0.54111475],
#           [0.37959546, 0.36344445, 0.45611593, ..., 0.5488144 ,
#            0.5372024 , 0.5450198 ],
#           [0.34117648, 0.42113808, 0.38052693, ..., 0.57604796,
#            0.52949834, 0.51029724]],
#
#          [[0.27842495, 0.24798228, 0.29016957, ..., 0.29391685,
#            0.26291725, 0.24314028],
#           [0.25496516, 0.23162866, 0.23598883, ..., 0.23610981,
#            0.22020027, 0.27748728],
#           [0.22348714, 0.20357741, 0.1691984 , ..., 0.25967342,
#            0.33706492, 0.33696425],
#           ...,
#           [0.23531775, 0.24152453, 0.31001917, ..., 0.24854717,
#            0.26284614, 0.2862657 ],
#           [0.21481684, 0.18668343, 0.18907955, ..., 0.29000577,
#            0.27059188, 0.28243122],
#           [0.18039216, 0.24302725, 0.11094034, ..., 0.30546206,
#            0.2550022 , 0.23978445]]], dtype=float32)),
#  (7,
#   3,
#   array([[[2.4313727e-01, 8.2932428e-02, 3.5426197e-06, ...,
# ...
#           [0.6078191 , 0.58431894, 0.5725387 , ..., 0.56864256,
#            0.5862921 , 0.576204  ],
#           [0.6194657 , 0.5843012 , 0.5686402 , ..., 0.56760144,
#            0.5157663 , 0.40453216],
#           [0.60784996, 0.5687171 , 0.5608108 , ..., 0.58012414,
#            0.43159282, 0.28152308]],
#
#          [[0.6272886 , 0.54512954, 0.58849365, ..., 0.23982018,
#            0.2423465 , 0.37786734],
#           [0.6235103 , 0.60043365, 0.63937604, ..., 0.41139507,
#            0.41935852, 0.59703356],
#           [0.6627474 , 0.666628  , 0.65881246, ..., 0.63786536,
#            0.7097787 , 0.7058824 ],
#           ...,
#           [0.67056537, 0.65882593, 0.67064065, ..., 0.6823653 ,
#            0.6742697 , 0.66362345],
#           [0.68231016, 0.67060393, 0.6901747 , ..., 0.67536294,
#            0.523696  , 0.39452296],
#           [0.68235296, 0.69014657, 0.69018996, ..., 0.6976818 ,
#            0.48739573, 0.28982615]]], dtype=float32)),
#  (7,
#   5,
#   array([[[0.24313726, 0.21576981, 0.19611552, ..., 0.22746722,
#            0.23155728, 0.20508002],
#           [0.25931638, 0.22736926, 0.20774123, ..., 0.2665242 ,
#            0.2627268 , 0.2627767 ],
#           [0.3020099 , 0.25084755, 0.2194249 , ..., 0.25428686,
#            0.22395062, 0.27778444],
#           ...,
#           [0.23921597, 0.22362038, 0.23156047, ..., 0.38737428,
#            0.28647372, 0.25098142],
#           [0.24313809, 0.22366904, 0.24706103, ..., 0.3832042 ,
#            0.30637386, 0.2631199 ],
#           [0.24705882, 0.23137434, 0.23531404, ..., 0.3742875 ,
#            0.33751866, 0.3099757 ]],
#
#          [[0.24705882, 0.21969138, 0.20003709, ..., 0.2902164 ,
#            0.28647253, 0.2676365 ],
#           [0.26720434, 0.23519073, 0.21166301, ..., 0.3252679 ,
#            0.31762964, 0.3176627 ],
#           [0.31377465, 0.25869066, 0.2271023 , ..., 0.30526316,
#            0.27493197, 0.32491586],
#           ...,
#           [0.23529412, 0.21969613, 0.22762954, ..., 0.49961948,
#            0.4197507 , 0.36470523],
#           [0.23529328, 0.21581647, 0.23921534, ..., 0.48477566,
#            0.41591313, 0.35709307],
#           [0.23137255, 0.21568805, 0.21963222, ..., 0.4000696 ,
#            0.36494032, 0.33352965]],
#
#          [[0.21568628, 0.18831885, 0.17259142, ..., 0.19607301,
#            0.23537122, 0.20474088],
#           [0.20035844, 0.18431868, 0.18032376, ..., 0.2308035 ,
#            0.25880304, 0.23926833],
#           [0.23147081, 0.20005186, 0.19599512, ..., 0.21560518,
#            0.21182723, 0.2311951 ],
#           ...,
#           [0.25882354, 0.24322557, 0.25118047, ..., 0.34266597,
#            0.3020239 , 0.30588102],
#           [0.25882354, 0.23935062, 0.26274753, ..., 0.31202525,
#            0.2903452 , 0.29028374],
#           [0.25882354, 0.24313903, 0.247081  , ..., 0.29910314,
#            0.30582374, 0.31757343]]], dtype=float32)),
#  (7,
#   3,
#   array([[[0.20000087, 0.18792541, 0.16473798, ..., 0.172536  ,
#            0.18826115, 0.18828729],
#           [0.203707  , 0.17591056, 0.16080537, ..., 0.18818161,
#            0.20018631, 0.20402452],
#           [0.19218342, 0.15337971, 0.15305665, ..., 0.21194452,
#            0.219813  , 0.22354361],
#           ...,
#           [0.3999984 , 0.3961038 , 0.41567403, ..., 0.29285192,
#            0.33331382, 0.3608743 ],
#           [0.41566518, 0.41923565, 0.3961158 , ..., 0.31462163,
#            0.34010708, 0.38384914],
#           [0.42352474, 0.42740005, 0.40784314, ..., 0.34510183,
#            0.36006364, 0.4037926 ]],
#
#          [[0.16862746, 0.15258875, 0.12552816, ..., 0.1215556 ,
#            0.13728076, 0.1373069 ],
#           [0.1684206 , 0.14056599, 0.1215956 , ..., 0.13720675,
#            0.14924271, 0.15306473],
#           [0.16080204, 0.11810056, 0.11376398, ..., 0.1648857 ,
#            0.17275418, 0.17648481],
#           ...,
#           [0.39607194, 0.3882858 , 0.4078252 , ..., 0.210276  ,
#            0.23920065, 0.26681665],
#           [0.403911  , 0.407431  , 0.38042358, ..., 0.24049714,
#            0.25770593, 0.3053023 ],
#           [0.40392157, 0.4077982 , 0.38823265, ..., 0.29410788,
#            0.30848697, 0.3527704 ]],
#
#          [[0.19607931, 0.16038932, 0.12945561, ..., 0.1490131 ,
#            0.16863962, 0.1608283 ],
#           [0.19962165, 0.14835864, 0.12552308, ..., 0.16074404,
#            0.1766154 , 0.17263138],
#           [0.18826187, 0.12601972, 0.11783951, ..., 0.1805858 ,
#            0.19227697, 0.18825035],
#           ...,
#           [0.38823208, 0.38820556, 0.4156766 , ..., 0.17166702,
#            0.2078242 , 0.24331722],
#           [0.3960679 , 0.4075334 , 0.38826236, ..., 0.20916459,
#            0.23003018, 0.28948158],
#           [0.39999768, 0.4117258 , 0.39608377, ..., 0.26273355,
#            0.28095073, 0.33705708]]], dtype=float32)),
#  (3,
#   9,
#   array([[[1.        , 1.        , 1.        , ..., 0.8980392 ,
#            0.9490196 , 0.9843137 ],
#           [1.        , 0.99607843, 0.99607843, ..., 0.8784314 ,
#            0.79607844, 0.95686275],
#           [1.        , 0.99607843, 1.        , ..., 0.9882353 ,
#            0.8980392 , 0.7882353 ],
#           ...,
#           [0.96862745, 0.9647059 , 0.9764706 , ..., 0.84313726,
#            0.85490197, 0.84705883],
#           [0.95686275, 0.9490196 , 0.9529412 , ..., 0.53333336,
#            0.4392157 , 0.34901962],
#           [0.9411765 , 0.9254902 , 0.9372549 , ..., 0.29411766,
#            0.3529412 , 0.41568628]],
#
#          [[1.        , 1.        , 1.        , ..., 0.7647059 ,
#            0.9372549 , 1.        ],
#           [1.        , 0.99607843, 0.99607843, ..., 0.77254903,
#            0.6392157 , 0.8745098 ],
#           [1.        , 0.99607843, 1.        , ..., 1.        ,
#            0.78039217, 0.6431373 ],
#           ...,
#           [0.8039216 , 0.7921569 , 0.79607844, ..., 0.6039216 ,
#            0.6039216 , 0.58431375],
#           [0.7921569 , 0.78039217, 0.78431374, ..., 0.3529412 ,
#            0.2784314 , 0.20784314],
#           [0.7921569 , 0.78039217, 0.78431374, ..., 0.2509804 ,
#            0.31764707, 0.38039216]],
#
#          [[1.        , 1.        , 1.        , ..., 0.5529412 ,
#            0.8509804 , 1.        ],
#           [1.        , 0.99607843, 0.99607843, ..., 0.6666667 ,
#            0.4745098 , 0.7490196 ],
#           [1.        , 0.99607843, 1.        , ..., 1.        ,
#            0.6509804 , 0.45882353],
#           ...,
#           [0.5176471 , 0.5137255 , 0.52156866, ..., 0.20784314,
#            0.23529412, 0.23529412],
#           [0.48235294, 0.49019608, 0.50980395, ..., 0.14117648,
#            0.10980392, 0.09411765],
#           [0.49803922, 0.5019608 , 0.52156866, ..., 0.18039216,
#            0.19607843, 0.19607843]]], dtype=float32)),
#  (6,
#   3,
#   array([[[0.37730393, 0.5022004 , 0.5523298 , ..., 0.36618605,
#            0.4274446 , 0.4077484 ],
#           [0.48168376, 0.5091637 , 0.33922943, ..., 0.3307783 ,
#            0.36295277, 0.40388343],
#           [0.39273283, 0.29189786, 0.22479397, ..., 0.16096595,
#            0.2208485 , 0.37525922],
#           ...,
#           [0.41291508, 0.37610674, 0.48527312, ..., 0.50134635,
#            0.5935203 , 0.65585285],
#           [0.32596466, 0.2607516 , 0.3524361 , ..., 0.5578643 ,
#            0.66208935, 0.7254902 ],
#           [0.29298007, 0.25107175, 0.2767876 , ..., 0.65298563,
#            0.760095  , 0.72718024]],
#
#          [[0.26944566, 0.37925914, 0.43421283, ..., 0.22616488,
#            0.27842885, 0.2703511 ],
#           [0.35586366, 0.3498232 , 0.21234259, ..., 0.2085842 ,
#            0.23095223, 0.26270714],
#           [0.25220475, 0.15690024, 0.10660634, ..., 0.10303423,
#            0.12792256, 0.2482812 ],
#           ...,
#           [0.3268377 , 0.38351977, 0.4393949 , ..., 0.36534184,
#            0.42323342, 0.47835648],
#           [0.21324861, 0.29498455, 0.40513182, ..., 0.4044193 ,
#            0.4740429 , 0.5334975 ],
#           [0.15531111, 0.22398598, 0.35256535, ..., 0.50164515,
#            0.57962626, 0.5430543 ]],
#
#          [[0.09763046, 0.10547787, 0.1384421 , ..., 0.0935333 ,
#            0.11372295, 0.1051487 ],
#           [0.13662142, 0.09198982, 0.07378516, ..., 0.0865266 ,
#            0.0875811 , 0.08241148],
#           [0.09330271, 0.0581311 , 0.03883488, ..., 0.0637778 ,
#            0.05872523, 0.09438312],
#           ...,
#           [0.08815855, 0.11720587, 0.14635634, ..., 0.14751208,
#            0.16417363, 0.1688839 ],
#           [0.1013181 , 0.11149971, 0.1222991 , ..., 0.15193154,
#            0.14910327, 0.17287733],
#           [0.0712152 , 0.08632669, 0.10102148, ..., 0.18166575,
#            0.19977023, 0.18879864]]], dtype=float32)),
#  (3,
#   5,
#   array([[[0.3843147 , 0.4117646 , 0.39999998, ..., 0.21173513,
#            0.11372586, 0.1372553 ],
#           [0.3921575 , 0.4156857 , 0.40000066, ..., 0.145098  ,
#            0.14509739, 0.17646876],
#           [0.39607942, 0.43137243, 0.42745093, ..., 0.14117706,
#            0.20391871, 0.14511031],
#           ...,
#           [0.07451504, 0.15296675, 0.25105166, ..., 0.28627452,
#            0.28235295, 0.28627452],
#           [0.06274508, 0.10980427, 0.15295011, ..., 0.2784314 ,
#            0.28627434, 0.28627452],
#           [0.05098039, 0.07450961, 0.09411759, ..., 0.2627451 ,
#            0.26274526, 0.26666668]],
#
#          [[0.29804018, 0.3254901 , 0.3137255 , ..., 0.3176141 ,
#            0.203922  , 0.21960819],
#           [0.30588302, 0.3294112 , 0.31372625, ..., 0.25098002,
#            0.23529367, 0.2549003 ],
#           [0.3098049 , 0.34509793, 0.34509796, ..., 0.23921652,
#            0.29411376, 0.21570228],
#           ...,
#           [0.05882827, 0.1294353 , 0.21967198, ..., 0.19607843,
#            0.19607843, 0.19607846],
#           [0.05490195, 0.09411792, 0.12941992, ..., 0.1921569 ,
#            0.19999981, 0.19999997],
#           [0.05098039, 0.062745  , 0.07843133, ..., 0.17647061,
#            0.17647074, 0.18039215]],
#
#          [[0.2078441 , 0.235294  , 0.2235294 , ..., 0.47055408,
#            0.34902006, 0.3450981 ],
#           [0.2156869 , 0.2392151 , 0.22353019, ..., 0.40784237,
#            0.37647045, 0.35294083],
#           [0.21960881, 0.25490183, 0.25490192, ..., 0.38039356,
#            0.41175818, 0.28238016],
#           ...,
#           [0.02745514, 0.09021759, 0.17260945, ..., 0.10196076,
#            0.09803922, 0.10196079],
#           [0.02352941, 0.05882378, 0.09020346, ..., 0.1019608 ,
#            0.10980336, 0.10980386],
#           [0.02352941, 0.03137248, 0.03921567, ..., 0.08627453,
#            0.09019619, 0.09019608]]], dtype=float32)),
#  (5,
#   3,
#   array([[[0.32156864, 0.35290927, 0.3807214 , ..., 0.22352163,
#            0.20783357, 0.19217291],
#           [0.360718  , 0.39212346, 0.4161423 , ..., 0.25866953,
#            0.2508861 , 0.23532018],
#           [0.41175285, 0.42744485, 0.44721782, ..., 0.29846627,
#            0.26299262, 0.24754162],
#           ...,
#           [0.7020423 , 0.75689596, 0.7770527 , ..., 0.7486709 ,
#            0.7104493 , 0.66314924],
#           [0.725407  , 0.7564876 , 0.8039056 , ..., 0.7262257 ,
#            0.66168135, 0.6125544 ],
#           [0.68235296, 0.68235296, 0.76470405, ..., 0.6786184 ,
#            0.61219984, 0.57254905]],
#
#          [[0.18431373, 0.20390163, 0.223875  , ..., 0.10196079,
#            0.10195599, 0.09412423],
#           [0.22346313, 0.24310665, 0.2593488 , ..., 0.13318954,
#            0.12150493, 0.10590345],
#           [0.26273322, 0.27842522, 0.29807132, ..., 0.14533827,
#            0.12179255, 0.11027636],
#           ...,
#           [0.57648546, 0.61962295, 0.6320445 , ..., 0.611416  ,
#            0.57314837, 0.5258942 ],
#           [0.56065583, 0.6112934 , 0.67055804, ..., 0.58878607,
#            0.52442646, 0.47529945],
#           [0.49411765, 0.5291519 , 0.62744886, ..., 0.54131615,
#            0.4710535 , 0.42745098]],
#
#          [[0.14117648, 0.16468196, 0.18458432, ..., 0.09020192,
#            0.10195839, 0.09803992],
#           [0.17249599, 0.19605207, 0.215809  , ..., 0.11750775,
#            0.09801564, 0.0862959 ],
#           [0.18821946, 0.20391484, 0.21977296, ..., 0.10599571,
#            0.0904043 , 0.09851488],
#           ...,
#           [0.43526256, 0.47060636, 0.47918633, ..., 0.45847592,
#            0.41632634, 0.3729542 ],
#           [0.39205855, 0.45835415, 0.52153426, ..., 0.44348204,
#            0.37531525, 0.33010867],
#           [0.34117648, 0.39178142, 0.49411538, ..., 0.4079597 ,
#            0.337657  , 0.29803923]]], dtype=float32)),
#  (4,
#   2,
#   array([[[0.5098108 , 0.5293891 , 0.5411716 , ..., 0.5097877 ,
#            0.50980395, 0.49808896],
#           [0.5058901 , 0.52540493, 0.53727317, ..., 0.5020686 ,
#            0.50213367, 0.4941547 ],
#           [0.48627758, 0.5058744 , 0.5177719 , ..., 0.5333055 ,
#            0.52147347, 0.5019965 ],
#           ...,
#           [0.3246862 , 0.37538347, 0.3725504 , ..., 0.3647759 ,
#            0.34076062, 0.30240986],
#           [0.2706715 , 0.32533553, 0.345192  , ..., 0.35670912,
#            0.32942107, 0.28736684],
#           [0.29409695, 0.30195588, 0.3295097 , ..., 0.34117016,
#            0.33333242, 0.3294124 ]],
#
#          [[0.5568696 , 0.5764479 , 0.58823043, ..., 0.5607681 ,
#            0.56078434, 0.5412594 ],
#           [0.55294883, 0.57246375, 0.5843319 , ..., 0.55304897,
#            0.5531141 , 0.541232  ],
#           [0.53333646, 0.5529332 , 0.56483066, ..., 0.58428586,
#            0.57245386, 0.5529706 ],
#           ...,
#           [0.39521697, 0.44205233, 0.4431386 , ..., 0.43536413,
#            0.41134882, 0.3729981 ],
#           [0.33734408, 0.39200222, 0.4118688 , ..., 0.42729732,
#            0.4000093 , 0.35795504],
#           [0.36076358, 0.3686225 , 0.39617637, ..., 0.4117584 ,
#            0.40392065, 0.40000063]],
#
#          [[0.4000069 , 0.41958508, 0.43136767, ..., 0.39214063,
#            0.39215687, 0.3804419 ],
#           [0.39608613, 0.415601  , 0.4274692 , ..., 0.3844215 ,
#            0.3844866 , 0.37651736],
#           [0.37647367, 0.39607048, 0.40796795, ..., 0.41565847,
#            0.4038264 , 0.38825494],
#           ...,
#           [0.25017637, 0.29703775, 0.29795069, ..., 0.27065822,
#            0.24671908, 0.21606675],
#           [0.19616169, 0.25082576, 0.2706822 , ..., 0.26259145,
#            0.2353034 , 0.2048188 ],
#           [0.22350521, 0.22744852, 0.2549999 , ..., 0.24705252,
#            0.2392166 , 0.24313663]]], dtype=float32)),
#  (2,
#   6,
#   array([[[0.54901963, 0.55291325, 0.53317106, ..., 0.34511393,
#            0.26716036, 0.2206976 ],
#           [0.5490194 , 0.58038723, 0.5799022 , ..., 0.30164933,
#            0.26279902, 0.25947103],
#           [0.5451241 , 0.57630706, 0.5789396 , ..., 0.32085752,
#            0.2708025 , 0.30574232],
#           ...,
#           [0.23112904, 0.16096887, 0.25816557, ..., 0.658557  ,
#            0.5056723 , 0.43921432],
#           [0.2588245 , 0.1893834 , 0.42977035, ..., 0.50324136,
#            0.38723597, 0.33776852],
#           [0.31371588, 0.3372275 , 0.7133367 , ..., 0.4471851 ,
#            0.33791152, 0.38039216]],
#
#          [[0.52156866, 0.51761913, 0.4979716 , ..., 0.34512186,
#            0.2866448 , 0.22473963],
#           [0.5019603 , 0.5254663 , 0.5291405 , ..., 0.30174553,
#            0.27064055, 0.25142843],
#           [0.4941373 , 0.5057141 , 0.5203172 , ..., 0.31700227,
#            0.27066386, 0.2822596 ],
#           ...,
#           [0.18815026, 0.16115375, 0.2683999 , ..., 0.62623066,
#            0.44425035, 0.36862615],
#           [0.19607905, 0.18102801, 0.42271295, ..., 0.46462977,
#            0.3286277 , 0.2710821 ],
#           [0.23136635, 0.3136296 , 0.66810256, ..., 0.4081167 ,
#            0.2751967 , 0.31764707]],
#
#          [[0.26666668, 0.30196637, 0.3059094 , ..., 0.15694219,
#            0.12958455, 0.11032514],
#           [0.28627506, 0.3097837 , 0.30566654, ..., 0.10998669,
#            0.10981828, 0.13373964],
#           [0.2941056 , 0.2939692 , 0.28896505, ..., 0.11751532,
#            0.11015794, 0.16461253],
#           ...,
#           [0.05112032, 0.08790877, 0.2661245 , ..., 0.52940416,
#            0.33889586, 0.2705869 ],
#           [0.07058924, 0.14874017, 0.42772436, ..., 0.36312294,
#            0.21897651, 0.16914107],
#           [0.12940145, 0.3017598 , 0.67565084, ..., 0.30236763,
#            0.16152872, 0.20784314]]], dtype=float32)),
#  ...]
